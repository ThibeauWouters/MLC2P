# %%
# Standard libraries
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],  # "Times", "Palatino", "New Century Schoolbook", "Bookman", 
    "axes.labelsize": 16
    })
import random
import csv
import pandas as pd
import h5py
import yt
# Own scripts:
# %load_ext autoreload
# %autoreload 2
import physics
import data
import nnc2p
# from nnc2p import NeuralNetwork # our own architecture
# Get dirs
import os
cwd = os.getcwd()# "Code" folder
master_dir = os.path.abspath(os.path.join(cwd, ".."))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Introduction

# %% [markdown]
# We can run a few simulations in Gmunu. Looking at the .dat files (output from the simulations) is a bit trickier. Hence, we load them here and postprocess/discuss/plot the data in this Python notebook.

# %% [markdown]
# # Smooth sine wave

# %% [markdown]
# Define the analytic results

# %%
A = 0.2
v0 = 0.2
theta = 0.0

def rho_sol_pt(x,y,t):
    return 1.0 + A * np.sin(2.0 * np.pi * ( ( x * np.cos(theta) + y * np.sin(theta) ) - ( v0 * np.cos(theta) ) * t ) )

rho_sol = np.vectorize(rho_sol_pt)

def gamma(field, data):
    return  np.sqrt( 1.0 + (data['W_vel1']**2) )
def veloc1(field, data):
    return data['W_vel1'] / data['gamma']

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
fname = os.path.join(master_dir, "Data/kastaun_wave.dat")
kastaun_wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/neuralnet_wave.dat")
neuralnet_wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/mock_table_wave.dat")
mock_table_wave = yt.load(fname)
# Out:
# yt : [INFO     ] 2023-05-25 10:44:34,371 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-05-25 10:44:34,393 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-05-25 10:44:34,426 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-25 10:44:34,439 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-25 10:44:34,442 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-25 10:44:35,052 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-05-25 10:44:35,060 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-05-25 10:44:35,060 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-25 10:44:35,070 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-25 10:44:35,093 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-25 10:44:35,487 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-05-25 10:44:35,487 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-05-25 10:44:35,495 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-25 10:44:35,495 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-25 10:44:35,504 Parameters: cosmological_simulation   = 0

# %%
# Final time of simulation 
T_final = float(kastaun_wave.current_time)
# Additional preprocessing - see Gmunu for the source of this
for wave in [kastaun_wave, neuralnet_wave, mock_table_wave]:
    # Add gamma and veloc1
    wave.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    wave.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
# Get the plotdata
plotdata_kastaun   = kastaun_wave.ortho_ray(0, (0, 0))
plotdata_neuralnet = neuralnet_wave.ortho_ray(0, (0, 0))
plotdata_mock_table = mock_table_wave.ortho_ray(0, (0, 0))
# Out:
# yt : [WARNING  ] 2023-05-25 10:44:37,743 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# ## Both waves

# %%
a = np.array([0,1,2])
a[:2]
# Out:
# array([0, 1])

# %%
waves = [kastaun_wave, neuralnet_wave, mock_table_wave]
labels = ["Kastaun", "NNC2P", "Mock EOS table"]
colors = ["red", "blue", "green"]
markers = ["^", "v", "o"]
fillstyle = "none"
ms=3
lw=1
alpha = 1

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2

fig, axs = plt.subplots(1, 2, figsize=(11,3))
(ax1, ax2) = axs

for i, wave in enumerate(waves[:limit]):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))

    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    
    # Exact values for this simulation
    if i == 0:
        exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
        exact_eps = (3/2) * (1/exact_vals)
        ax1.plot(np.array(plotdata['x'][srt]), exact_vals, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
        ax2.plot(np.array(plotdata['x'][srt]), exact_eps, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
    # The approximation
    ax1.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]), linestyle='',  color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    ax2.plot(np.array(plotdata['x'][srt]), np.array(plotdata['eps'][srt]), linestyle='', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    
# Make a nice plot
ax1.set_ylabel(r"$\rho$")
ax2.set_ylabel(r"$\varepsilon$")
for ax in axs:
    ax.set_xlabel(r"$x$")
    ax.set_xlabel(r"$x$")
    ax.grid()
ax1.legend()
# plt.title("Smooth sine wave test")
if limit == 2:
    plt.savefig(os.path.join(master_dir, "Plots/smooth_wave_rho_kastaun_neuralnet.pdf"), bbox_inches='tight')
else:
    plt.savefig(os.path.join(master_dir, "Plots/smooth_wave_rho_kastaun_neuralnet_mock.pdf"), bbox_inches='tight')
plt.show()

# %%
print(f"{len(plotdata['x'][srt])} points in the plot")
# Out:
# 128 points in the plot

# %%
waves = [kastaun_wave, neuralnet_wave, mock_table_wave]
labels = ["Kastaun", "Neural net", "Mock EOS table"]
plotstyles = ["r-", "b-", "g-"]

for i, wave in enumerate(waves):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))

    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    
    # Exact values for this simulation
    exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    # Difference with numerical solution
    diffs = abs(np.array(plotdata['rho'][srt]) - exact_vals)
    plt.plot(diffs, plotstyles[i], label = labels[i], lw = 1)

plt.grid()
plt.legend()
plt.xlabel("x")
plt.yscale('log')
plt.ylabel("Diffs rho")
plt.title("Smooth sine wave test")
plt.savefig(os.path.join(master_dir, "Plots/smooth_wave_rho_kastaun_neuralnet_diffs.pdf"), bbox_inches='tight')
plt.show()

# %%
np.max(diffs)
# Out:
# 0.019730106370019262

# %%
# plotdata.__dict__.keys()

# %% [markdown]
# __TODO__ how to get other entries in the .dat file?

# %% [markdown]
# # Shocktube

# %%
# Load the datasets
kastaun_shock = yt.load(os.path.join(master_dir, "Data/kastaun_shock.dat"))
kastaun_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
kastaun_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

neuralnet_shock = yt.load(os.path.join(master_dir, "Data/neuralnet_shock.dat"))
neuralnet_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
neuralnet_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

mock_table_shock = yt.load(os.path.join(master_dir, "Data/mock_table_shock.dat"))
mock_table_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
mock_table_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')
# Out:
# yt : [INFO     ] 2023-05-11 10:12:45,430 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-05-11 10:12:45,431 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-05-11 10:12:45,431 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 10:12:45,432 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 10:12:45,433 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-05-11 10:12:45,459 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-05-11 10:12:45,644 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-05-11 10:12:45,645 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-05-11 10:12:45,646 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 10:12:45,647 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 10:12:45,648 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-05-11 10:12:45,674 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-05-11 10:12:45,889 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-05-11 10:12:45,890 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-05-11 10:12:45,891 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 10:12:45,893 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 10:12:45,895 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-05-11 10:12:45,936 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# Get the data

# %%
# cutting the x-axis through the y=0,z=0 
plotdata_kastaun = kastaun_shock.ortho_ray( 0, (0, 0) )
plotdata_neuralnet = neuralnet_shock.ortho_ray( 0, (0, 0) )
plotdata_mock_table = mock_table_shock.ortho_ray( 0, (0, 0) )

# Sort the ray values by 'x' so there are no discontinuities in the line plot
kastaun_srt = np.argsort(plotdata_kastaun['x'])
neuralnet_srt = np.argsort(plotdata_neuralnet['x'])
mock_table_srt = np.argsort(plotdata_mock_table['x'])

# %% [markdown]
# Reference:

# %%
# Plot the data
plotdata = plotdata_kastaun
srt = np.argsort(plotdata['x'])
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), label='rho/10')
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), label='P/20')
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), label='v')

# Save the line plot
plt.legend(loc='best')
plt.title("Kastaun")
plt.grid()
plt.show()

# %%
# Plot the data
plotdata = plotdata_mock_table
srt = np.argsort(plotdata['x'])
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), label='rho/10')
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), label='P/20')
plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), label='v')

# Save the line plot
plt.legend(loc='best')
plt.title("Mock table")
plt.grid()
plt.show()

# %% [markdown]
# # Convergence plots

# %% [markdown]
# Directory location:

# %%
conv_wave_dir = os.path.join(master_dir, "Data/convergence_results/conv_wave")
conv_shock_dir = os.path.join(master_dir, "Data/convergence_results/conv_shocktube")

# %% [markdown]
# The grid sizes that were used:

# %%
grid_sizes = [100, 200, 400, 800, 1600, 3200]

# %% [markdown]
# ## Smooth sine wave

# %% [markdown]
# The analytic solution to the problem:

# %% [markdown]
# TODO - get the neural net error on the prims for a very large sample?

# %%
A = 0.2
v0 = 0.2
theta = 0.0

def rho_sol_pt(x,y,t):
    return 1.0 + A * np.sin(2.0 * np.pi * ( ( x * np.cos(theta) + y * np.sin(theta) ) - ( v0 * np.cos(theta) ) * t ) )

rho_sol = np.vectorize(rho_sol_pt)

def gamma(field, data):
    return  np.sqrt( 1.0 + (data['W_vel1']**2) )
def veloc1(field, data):
    return data['W_vel1'] / data['gamma']

# %% [markdown]
# Auxiliary method to find the numerical error from a simulation file

# %%
def get_errors(dat):
    # Get the plotdata
    plotdata   = dat.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    # Get exact values and numerical solution values
    exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    num_vals = plotdata['rho'][srt]
    # Get the differences
    diffs = abs(np.array(plotdata['rho'][srt]) - exact_vals)
    # Append errors
    l1 = np.mean(diffs)
    linfty = np.max(diffs)
    
    return l1, linfty

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
kastaun_data = []
neuralnet_data = []
for grid_size in grid_sizes:
    # Kastaun:
    fname = os.path.join(conv_wave_dir, f"kastaun_{grid_size}.dat")
    dat = yt.load(fname)
    #wave.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    #wave.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    kastaun_data.append(dat)
    # Neuralnet:
    fname = os.path.join(conv_wave_dir, f"neuralnet_{grid_size}.dat")
    dat = yt.load(fname)
    neuralnet_data.append(dat)
# Out:
# yt : [INFO     ] 2023-05-11 15:27:00,127 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,128 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,130 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,131 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,204 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,205 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,207 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,208 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,209 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,291 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,292 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,293 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,294 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,295 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,371 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,373 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,376 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,377 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,378 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,470 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,474 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,475 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,476 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,477 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,582 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,583 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,584 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,585 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,587 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,681 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,682 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,683 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,684 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,685 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,767 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,768 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,769 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,771 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,773 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,856 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,857 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-05-11 15:27:00,858 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,860 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,860 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,936 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,937 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-05-11 15:27:00,940 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,941 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,942 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:01,039 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:01,041 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-05-11 15:27:01,042 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:01,043 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:01,044 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:01,131 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:01,132 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-05-11 15:27:01,133 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:01,134 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:01,135 Parameters: cosmological_simulation   = 0

# %%
# Final time of simulation 
T_final = 5.0

kastaun_l1 = []
kastaun_linfty = []

neuralnet_l1 = []
neuralnet_linfty = []

# Get the errors for each simulation
for dat in kastaun_data:
    l1, linfty = get_errors(dat)
    kastaun_l1.append(l1)
    kastaun_linfty.append(linfty)
    
for dat in neuralnet_data:
    l1, linfty = get_errors(dat)
    neuralnet_l1.append(l1)
    neuralnet_linfty.append(linfty)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize=(11,3))
alph = 0.5
ax1, ax2 = axs

ax1.plot(grid_sizes, kastaun_l1, '--o', color = "blue", label = "Rootfinders", alpha=alph)
ax1.plot(grid_sizes, neuralnet_l1, '--o', color = "red", label = "NN", alpha=alph)
ax1.set_ylabel("L1 error")

ax2.plot(grid_sizes, kastaun_linfty, '--o', color = "blue", label = "Rootfinders", alpha=alph)
ax2.plot(grid_sizes, neuralnet_linfty, '--o', color = "red", label = "NN", alpha=alph)
ax2.set_ylabel("Linfty error")

for ax in axs:
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel("Grid size")
    ax.set_xticks(grid_sizes, labels=grid_sizes)
    ax.grid()
    ax.legend()
# plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_wave.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Shocktube

# %% [markdown]
# TODO - how do I get the analytic results?

# %%
def get_errors_shock(dat):
    # Get the plotdata
    plotdata   = dat.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    # Get exact values and numerical solution values
    exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    num_vals = plotdata['rho'][srt]
    # Get the differences
    diffs = abs(np.array(plotdata['rho'][srt]) - exact_vals)
    # Append errors
    l1 = np.mean(diffs)
    linfty = np.max(diffs)
    
    return l1, linfty

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
kastaun_data = []
neuralnet_data = []
for grid_size in grid_sizes:
    # Kastaun:
    fname = os.path.join(conv_shock_dir, f"kastaun_{grid_size}.dat")
    dat = yt.load(fname)
    #wave.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    #wave.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    kastaun_data.append(dat)
    # Neuralnet:
    fname = os.path.join(conv_shock_dir, f"neuralnet_{grid_size}.dat")
    dat = yt.load(fname)
    neuralnet_data.append(dat)
# Out:
# yt : [INFO     ] 2023-05-11 15:27:00,127 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,128 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,130 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,131 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,204 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,205 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,207 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,208 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,209 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,291 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,292 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,293 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,294 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,295 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,371 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,373 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,376 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,377 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,378 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,470 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,474 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,475 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,476 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,477 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,582 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,583 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,584 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,585 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,587 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,681 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,682 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,683 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,684 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,685 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,767 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,768 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-05-11 15:27:00,769 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,771 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,773 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,856 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,857 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-05-11 15:27:00,858 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,860 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,860 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:00,936 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:00,937 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-05-11 15:27:00,940 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:00,941 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:00,942 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:01,039 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:01,041 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-05-11 15:27:01,042 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:01,043 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:01,044 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-11 15:27:01,131 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-05-11 15:27:01,132 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-05-11 15:27:01,133 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-11 15:27:01,134 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-11 15:27:01,135 Parameters: cosmological_simulation   = 0

# %%
# Final time of simulation 
T_final = 5.0

kastaun_l1 = []
kastaun_linfty = []

neuralnet_l1 = []
neuralnet_linfty = []

# Get the errors for each simulation
for dat in kastaun_data:
    l1, linfty = get_errors(dat)
    kastaun_l1.append(l1)
    kastaun_linfty.append(linfty)
    
for dat in neuralnet_data:
    l1, linfty = get_errors(dat)
    neuralnet_l1.append(l1)
    neuralnet_linfty.append(linfty)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize=(11,3))
alph = 0.5
ax1, ax2 = axs

ax1.plot(grid_sizes, kastaun_l1, '--o', color = "blue", label = "Rootfinders", alpha=alph)
ax1.plot(grid_sizes, neuralnet_l1, '--o', color = "red", label = "NN", alpha=alph)
ax1.set_ylabel("L1 error")

ax2.plot(grid_sizes, kastaun_linfty, '--o', color = "blue", label = "Rootfinders", alpha=alph)
ax2.plot(grid_sizes, neuralnet_linfty, '--o', color = "red", label = "NN", alpha=alph)
ax2.set_ylabel("Linfty error")

for ax in axs:
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel("Grid size")
    ax.set_xticks(grid_sizes, labels=grid_sizes)
    ax.grid()
    ax.legend()
# plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_wave.pdf"), bbox_inches='tight')
plt.show()
