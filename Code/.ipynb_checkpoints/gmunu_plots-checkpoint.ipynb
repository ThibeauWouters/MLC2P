# %%
# Standard libraries
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random
import csv
import pandas as pd
import h5py
import yt
# Own scripts:
# %load_ext autoreload
# %autoreload 2
import physics
import data
import nnc2p
# from nnc2p import NeuralNetwork # our own architecture
# Get dirs
import os
cwd = os.getcwd()# "Code" folder
master_dir = os.path.abspath(os.path.join(cwd, ".."))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fs_labels = 16
fs_ticks  = 12
fs_legend = 12

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],  # "Times", "Palatino", "New Century Schoolbook", "Bookman", 
    })
plt.rcParams['font.size'] = fs_labels
plt.rcParams['axes.titlesize'] = fs_labels
plt.rcParams['axes.labelsize'] = fs_labels
plt.rcParams['xtick.labelsize'] = fs_ticks
plt.rcParams['ytick.labelsize'] = fs_ticks
plt.rcParams['legend.fontsize'] = fs_legend

# %%
def gamma(field, data):
    return  np.sqrt( 1.0 + (data['W_vel1']**2) )
def veloc1(field, data):
    return data['W_vel1'] / data['gamma']
def press(field, data):
    return ( eos_gamma - 1.0 ) * data['e']

# %% [markdown]
# # Introduction

# %% [markdown]
# We can run a few simulations in Gmunu. Looking at the .dat files (output from the simulations) is a bit trickier. Hence, we load them here and postprocess/discuss/plot the data in this Python notebook.

# %% [markdown]
# # Smooth sine wave

# %% [markdown]
# Define the analytic results

# %%
A = 0.2
v0 = 0.2
theta = 0.0

def rho_sol_pt(x,y,t):
    return 1.0 + A * np.sin(2.0 * np.pi * ( ( x * np.cos(theta) + y * np.sin(theta) ) - ( v0 * np.cos(theta) ) * t ) )

rho_sol = np.vectorize(rho_sol_pt)

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
fname = os.path.join(master_dir, "Data/kastaun_wave.dat")
kastaun_wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/neuralnet_wave.dat")
neuralnet_wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/mock_table_wave.dat")
mock_table_wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/sanity_check.dat")
assist_wave = yt.load(fname)

# Final time of simulation 
T_final = float(kastaun_wave.current_time)
# Additional preprocessing - see Gmunu for the source of this
for wave in [kastaun_wave, neuralnet_wave, mock_table_wave, assist_wave]:
    # Add gamma and veloc1
    wave.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    wave.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
# Get the plotdata
plotdata_kastaun    = kastaun_wave.ortho_ray(0, (0, 0))
plotdata_neuralnet  = neuralnet_wave.ortho_ray(0, (0, 0))
plotdata_mock_table = mock_table_wave.ortho_ray(0, (0, 0))
plotdata_assist     = assist_wave.ortho_ray(0, (0, 0))
# Out:
# yt : [INFO     ] 2023-06-06 07:37:18,346 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-06-06 07:37:18,350 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 07:37:18,354 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 07:37:18,362 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 07:37:18,362 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-06 07:37:18,576 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-06-06 07:37:18,576 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 07:37:18,576 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 07:37:18,587 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 07:37:18,590 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-06 07:37:18,790 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-06-06 07:37:18,790 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 07:37:18,790 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 07:37:18,797 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 07:37:18,805 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-06 07:37:19,025 Parameters: current_time              = 2.0
# yt : [INFO     ] 2023-06-06 07:37:19,026 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 07:37:19,026 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 07:37:19,034 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 07:37:19,034 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 07:37:19,058 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Kastaun and NNC2P

# %%
waves = [kastaun_wave, neuralnet_wave, mock_table_wave]
labels = ["Kastaun", "NNC2P", "Mock EOS table"]
colors = ["red", "blue", "purple"]
markers = ["^", "v", "^"]
fillstyle = "none"
ms=5
lw=1
alpha = 1

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2

fig, axs = plt.subplots(1, 2, figsize=(11,3))
(ax1, ax2) = axs

for i, wave in enumerate(waves[:limit]):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))

    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    
    # Exact values for this simulation
    if i == 0:
        exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
        exact_eps = (3/2) * (1/exact_vals)
        ax1.plot(np.array(plotdata['x'][srt]), exact_vals, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
        ax2.plot(np.array(plotdata['x'][srt]), exact_eps, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
    # The approximation
    ax1.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]), linestyle='',  color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    ax2.plot(np.array(plotdata['x'][srt]), np.array(plotdata['eps'][srt]), linestyle='', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    
# Make a nice plot
ax1.set_ylabel(r"$\rho$")
ax2.set_ylabel(r"$\varepsilon$")
for ax in axs:
    ax.set_xlabel(r"$x$")
    ax.set_xlabel(r"$x$")
    ax.grid()
ax1.legend()
# plt.title("Smooth sine wave test")
if limit == 2:
    plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_kastaun_neuralnet.pdf"), bbox_inches='tight')
else:
    plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_kastaun_neuralnet_mock.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### NNC2P and mock EOS table

# %%
waves = [mock_table_wave, neuralnet_wave]
labels = ["Mock EOS table", "NNC2P"]
colors = ["red", "blue", "purple"]
markers = ["^", "v", "^"]
fillstyle = "none"
# ms=5
# lw=1
# alpha = 1

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2

fig, axs = plt.subplots(1, 2, figsize=(11,3))
(ax1, ax2) = axs

for i, wave in enumerate(waves[:limit]):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))

    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    
    # Exact values for this simulation
    if i == 0:
        exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
        exact_eps = (3/2) * (1/exact_vals)
        ax1.plot(np.array(plotdata['x'][srt]), exact_vals, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
        ax2.plot(np.array(plotdata['x'][srt]), exact_eps, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
    # The approximation
    ax1.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]), linestyle='',  color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    ax2.plot(np.array(plotdata['x'][srt]), np.array(plotdata['eps'][srt]), linestyle='', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    
# Make a nice plot
ax1.set_ylabel(r"$\rho$")
ax2.set_ylabel(r"$\varepsilon$")
for ax in axs:
    ax.set_xlabel(r"$x$")
    ax.set_xlabel(r"$x$")
    ax.grid()
ax1.legend()
plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_neuralnet_mock.pdf"), bbox_inches='tight')
plt.show()

# %%
print(f"{len(plotdata['x'][srt])} points in the plot")
# Out:
# 128 points in the plot

# %% [markdown]
# ## Differences

# %%
waves = [kastaun_wave, neuralnet_wave]
labels = ["Kastaun", "NNC2P"]
colors = ["red", "blue", "purple"]
markers = ["^", "v", "^"]
plotstyles = ["r^", "bv", "g^"]
fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
small_delta = 0

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2
plt.figure(figsize=(11, 3))
for i, wave in enumerate(waves[:limit]):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    # Exact values for this simulation
    if i == 0:
        exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    # Difference with numerical solution
    diffs_rho = abs(np.array(plotdata['rho'][srt]) - exact_vals)
    # Plot them
    plt.plot(np.array(plotdata['x'][srt]), diffs_rho, plotstyles[i], label = labels[i], fillstyle=fillstyle, lw = lw)

# Plot the line connecting them for clarity
plt.plot(np.array(plotdata['x'][srt]), diffs_rho, "-", color="gray",lw=0.5)
# Make a nice plot
plt.ylabel(r"$\Delta\rho$")
plt.xlabel(r"$x$")
plt.yscale('log')
plt.grid()
plt.legend()
# plt.title("Smooth sine wave test")
plt.ylim(1e-4 - small_delta, 1e-2 + small_delta)
plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_kastaun_neuralnet_diffs.pdf"), bbox_inches='tight')
plt.show()

# %%
print(f"The relative mean difference is: {np.mean(diffs_rho)} pm {np.std(diffs_rho)}")
print(f"The lowest and highest diff  is: {np.min(diffs_rho)} , {np.max(diffs_rho)}")
# Out:
# The relative mean difference is: 0.0017153544245694253 pm 0.0016315979001183896
# The lowest and highest diff  is: 0.00014942789295135928 , 0.006541703487670136

# %%
waves = [mock_table_wave, neuralnet_wave]
labels = ["Kastaun, Mock EOS table", "NNC2P"]
colors = ["red", "blue", "purple"]
markers = ["^", "v", "^"]
plotstyles = ["r^", "bv", "g^"]
fillstyle = "none"
ms=3
lw=1
alpha = 1
small_delta = 0

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2
plt.figure(figsize=(11, 3))
for i, wave in enumerate(waves[:limit]):
    # cutting the x-axis through the y=0,z=0 
    plotdata = wave.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    # Exact values for this simulation
    if i == 0:
        exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    # Difference with numerical solution
    diffs_rho = abs(np.array(plotdata['rho'][srt]) - exact_vals)
    # Plot them
    plt.plot(np.array(plotdata['x'][srt]), diffs_rho, plotstyles[i], label = labels[i], fillstyle=fillstyle, lw = lw)

# Plot the line connecting them for clarity
plt.plot(np.array(plotdata['x'][srt]), diffs_rho, "-", color="gray",lw=0.5)
# Make a nice plot
plt.ylabel(r"$\Delta\rho$")
plt.xlabel(r"$x$")
plt.yscale('log')
plt.grid()
plt.legend()
# plt.title("Smooth sine wave test")
plt.ylim(1e-4 - small_delta, 1e-2 + small_delta)
plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_mock_neuralnet_diffs.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Sanity check: mock table is different from exact Kastaun

# %%
kastaun_check = kastaun_wave.ortho_ray(0, (0, 0))
srt = np.argsort(kastaun_check['x'])
kastaun_rho_check = np.array(kastaun_check['rho'][srt])

mock_check = mock_table_wave.ortho_ray(0, (0, 0))
srt = np.argsort(mock_check['x'])
mock_rho_check = np.array(mock_check['rho'][srt])

diffs_kastaun_mock = abs(kastaun_rho_check - mock_rho_check)

plt.figure(figsize=(7,5))
plt.plot(np.array(mock_check['x'][srt]), diffs_kastaun_mock, linestyle='', marker="o", color="blue", label=r"|Kastaun - mock EOS table|", ms=6, fillstyle="none")
plt.plot(np.array(mock_check['x'][srt]), diffs_kastaun_mock, "-", color="gray", lw=1)
plt.grid()
# plt.legend()
plt.xlabel(r"$x$")
plt.ylabel(r"$\Delta\rho$")
plt.yscale('log')
plt.xticks(fontsize=fs_ticks+2)
plt.yticks(fontsize=fs_ticks+2)
plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_diffs_mock_and_kastaun.pdf"), bbox_inches='tight')
plt.show()

# %%
print(f"Average error by mock EOS table: {np.mean(diffs_kastaun_mock)}")
# Out:
# Average error by mock EOS table: 4.650274456266014e-06

# %% [markdown]
# __TODO__ how to get other entries in the .dat file?

# %% [markdown]
# ## Kastaun and NN assist

# %%
# waves = [kastaun_wave, assist_wave]
# labels = ["Kastaun", "NN assist"]
# colors = ["red", "blue", "purple"]
# markers = ["^", "v", "^"]
# fillstyle = "none"
# ms=3
# lw=1
# alpha = 1

# # Limit:
# # 2 -- don't plot mock EOS table
# # 3 -- plot mock EOS table
# limit = 2

# fig, axs = plt.subplots(1, 2, figsize=(11,3))
# (ax1, ax2) = axs

# for i, wave in enumerate(waves[:limit]):
#     # cutting the x-axis through the y=0,z=0 
#     plotdata = wave.ortho_ray(0, (0, 0))

#     # Sort the ray values by 'x' so there are no discontinuities in the line plot
#     srt = np.argsort(plotdata['x'])
    
#     # Exact values for this simulation
#     if i == 0:
#         exact_vals = np.array(rho_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
#         exact_eps = (3/2) * (1/exact_vals)
#         ax1.plot(np.array(plotdata['x'][srt]), exact_vals, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
#         ax2.plot(np.array(plotdata['x'][srt]), exact_eps, '-', color="black", label="Exact", lw=lw, alpha = alpha, zorder=1000)
#     # The approximation
#     ax1.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]), linestyle='',  color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
#     ax2.plot(np.array(plotdata['x'][srt]), np.array(plotdata['eps'][srt]), linestyle='', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    
# # Make a nice plot
# ax1.set_ylabel(r"$\rho$")
# ax2.set_ylabel(r"$\varepsilon$")
# for ax in axs:
#     ax.set_xlabel(r"$x$")
#     ax.set_xlabel(r"$x$")
#     ax.grid()
# ax1.legend()
# # plt.title("Smooth sine wave test")
# if limit == 2:
#     plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_kastaun_assist.pdf"), bbox_inches='tight')
# else:
#     plt.savefig(os.path.join(master_dir, "Plots/Final/smooth_wave_rho_kastaun_assist.pdf"), bbox_inches='tight')
# plt.show()

# %%
# mu_wave_assist = np.loadtxt("../Data/mu_wave_assist.dat")
# mu_wave = np.loadtxt("../Data/mu_wave.dat")
# plt.boxplot([mu_wave_assist, mu_wave])
# plt.show()

# %%
# mu_shock_assist = np.loadtxt("../Data/mu_shock_assist.dat")
# mu_shock = np.loadtxt("../Data/mu_shock.dat")
# plt.boxplot([mu_shock_assist, mu_shock])
# plt.show()

# %% [markdown]
# Compare the results from nn assist = false and computing NN on the side:

# %%
# # Get data
# mu = np.loadtxt("../Data/mu.dat")
# mu_guess = np.loadtxt("../Data/mu_guess.dat")
# mu_left, mu_right = mu_guess[:, 0], mu_guess[:, 1]
# width = 0.01 # see Gmunu code
# mu_hat = mu_right - width
# mu_err = width

# %%
# plt.errorbar(mu, mu_hat, yerr = mu_err, fmt = 'o', color="blue", markersize=2, capsize=5)
# xvals = np.arange(np.min(mu), np.max(mu), 0.001)
# plt.plot(xvals, xvals, "--", color = "black")
# plt.ylim(0, np.max(mu))
# plt.savefig("../Plots/relation_")
# plt.show()

# %%
# plt.plot(mu, mu_hat, "o", color="blue")
# plt.plot(xvals, xvals, "--", color = "black")
# plt.show()

# %% [markdown]
# What about the counts?

# %%
# # Get data
# counts = np.loadtxt("../Data/counts_wave.dat", dtype="object")
# counts_assist = np.loadtxt("../Data/counts_wave_assist.dat", dtype="object")
# # Convert second column to float
# counts = counts[:, 1].astype(float)
# counts_assist = counts_assist[:, 1].astype(float)

# %%
# print(np.mean(counts))
# print(np.mean(counts_assist))

# %% [markdown]
# # Shocktube

# %%
# Load the datasets
kastaun_shock = yt.load(os.path.join(master_dir, "Data/kastaun_shock.dat"))
kastaun_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
kastaun_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

neuralnet_shock = yt.load(os.path.join(master_dir, "Data/neuralnet_shock.dat"))
neuralnet_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
neuralnet_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

mock_table_shock = yt.load(os.path.join(master_dir, "Data/mock_table_shock.dat"))
mock_table_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
mock_table_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

assist_shock = yt.load(os.path.join(master_dir, "Data/assist_shock.dat"))
assist_shock.add_field( ('amrvac','gamma'), function=gamma, sampling_type='cell')
assist_shock.add_field( ('amrvac','veloc1'), function=veloc1, sampling_type='cell')

### File from Gmunu:
# exact_shocktube_press = np.loadtxt("../Data/convergence_results/conv_shocktube/exact_shocktube_press.txt", delimiter=",")
# exact_shocktube_rho   = np.loadtxt("../Data/convergence_results/conv_shocktube/exact_shocktube_rho.txt", delimiter=",")
# exact_shocktube_v     = np.loadtxt("../Data/convergence_results/conv_shocktube/exact_shocktube_v.txt", delimiter=",")

### Solution from Marti and Mueller
exact_shocktube = np.loadtxt("../Data/shock_solution_riemann_high_res.dat")
exact_shocktube_x     = np.array(exact_shocktube[:, 0])
exact_shocktube_press = np.array(exact_shocktube[:, 1]) / 20
exact_shocktube_rho   = np.array(exact_shocktube[:, 2]) / 10
exact_shocktube_vel   = np.array(exact_shocktube[:, 3])
exact_shocktube_eps   = (3/2) * exact_shocktube_press/exact_shocktube_rho
# Out:
# yt : [INFO     ] 2023-06-06 09:02:37,826 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 09:02:37,834 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-06-06 09:02:37,834 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 09:02:37,842 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 09:02:37,842 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 09:02:37,914 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 09:02:38,440 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 09:02:38,448 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-06-06 09:02:38,448 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 09:02:38,456 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 09:02:38,456 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 09:02:38,521 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 09:02:38,943 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 09:02:38,943 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-06-06 09:02:38,951 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 09:02:38,951 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 09:02:38,951 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 09:02:39,008 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 09:02:39,500 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 09:02:39,500 Parameters: domain_dimensions         = [16  1  1]
# yt : [INFO     ] 2023-06-06 09:02:39,500 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 09:02:39,508 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 09:02:39,508 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 09:02:39,532 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# Get the data

# %%
# cutting the x-axis through the y=0,z=0 
plotdata_kastaun = kastaun_shock.ortho_ray( 0, (0, 0) )
plotdata_neuralnet = neuralnet_shock.ortho_ray( 0, (0, 0) )
plotdata_mock_table = mock_table_shock.ortho_ray( 0, (0, 0) )
plotdata_assist = assist_shock.ortho_ray( 0, (0, 0) )

# Sort the ray values by 'x' so there are no discontinuities in the line plot
kastaun_srt = np.argsort(plotdata_kastaun['x'])
neuralnet_srt = np.argsort(plotdata_neuralnet['x'])
mock_table_srt = np.argsort(plotdata_mock_table['x'])
assist_srt = np.argsort(plotdata_assist['x'])

# %% [markdown]
# keys: rho, press, veloc1

# %% [markdown]
# ## Solutions

# %%
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# %% [markdown]
# Kastaun and neuralnet comparison

# %%
# Exact values for this simulation
# Have to get at other grid points using interpolation, use kastaun
srt = kastaun_srt
x_kastaun = np.array(plotdata_kastaun['x'][srt])
# exact_shocktube_press_2 = np.interp(x_kastaun, exact_shocktube_press[:, 0], exact_shocktube_press[:, 1])
# exact_shocktube_rho_2 = np.interp(x_kastaun, exact_shocktube_rho[:, 0], exact_shocktube_rho[:, 1])
# exact_shocktube_v_2 = np.interp(x_kastaun, exact_shocktube_v[:, 0], exact_shocktube_v[:, 1])

# Same for the neuralnet
srt = neuralnet_srt
x_neuralnet = np.array(plotdata_neuralnet['x'][srt])
# exact_shocktube_press_3 = np.interp(x_neuralnet, exact_shocktube_press[:, 0], exact_shocktube_press[:, 1])
# exact_shocktube_rho_3 = np.interp(x_neuralnet, exact_shocktube_rho[:, 0], exact_shocktube_rho[:, 1])
# exact_shocktube_v_3 = np.interp(x_neuralnet, exact_shocktube_v[:, 0], exact_shocktube_v[:, 1])

# %%
plotdata_list = [plotdata_kastaun, plotdata_neuralnet]
labels = ["Kastaun", "NNC2P"]
colors = ["red", "blue", "green"]
markers = ["^", "v", "^"]
fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
small_delta = 0

# Limit:
# 2 -- don't plot mock EOS table
# 3 -- plot mock EOS table
limit = 2
plt.figure(figsize=(11, 4))

# Plot the exact solution
plt.plot(exact_shocktube_x, exact_shocktube_rho, linestyle='-', color = "black", lw = lw, zorder=1000)
plt.plot(exact_shocktube_x, exact_shocktube_vel, linestyle='-', color = "black", lw = lw, zorder=1000)
plt.plot(exact_shocktube_x, exact_shocktube_press, linestyle='-', color = "black", lw = lw, zorder=1000)

for i, plotdata in enumerate(plotdata_list[:limit]):
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    
    # Difference with numerical solution
    # Plot them
    plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), linestyle='', color = "green", marker=markers[i], fillstyle=fillstyle, lw = lw)
    plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), linestyle='', color = "red", marker=markers[i], fillstyle=fillstyle, lw = lw)
    plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), linestyle='', color = "blue", marker=markers[i], fillstyle=fillstyle, lw = lw)

# Make a nice plot
plt.xlabel(r"$x$")
plt.grid()
# Nice legend:
# Define custom legend handles and labels
legend_handles = [
    mpatches.Patch(color='green'),
    mpatches.Patch(color='red'),
    mpatches.Patch(color='blue'),
    mlines.Line2D([], [], marker='^', color='black', linestyle='None', fillstyle="none"),
    mlines.Line2D([], [], marker='v', color='black', linestyle='None', fillstyle="none")
]
legend_labels = [r'$v$', r'$p/20$', r'$\rho/10$', 'Kastaun', 'NNC2P']
plt.legend(legend_handles, legend_labels, fontsize=12)
plt.savefig(os.path.join(master_dir, "Plots/Final/shocktube_rho_kastaun_neuralnet.pdf"), bbox_inches='tight')
plt.show()
# Out:
# yt : [WARNING  ] 2023-06-06 09:02:44,266 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 09:02:44,273 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 09:02:44,354 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 09:02:44,362 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless

# %% [markdown]
# Kastaun and NN assist comparison

# %%
# plotdata_list = [plotdata_kastaun, plotdata_assist]
# labels = ["Kastaun", "NN assist"]
# colors = ["red", "blue", "green"]
# markers = ["^", "v", "^"]
# fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
# small_delta = 0

# # Limit:
# # 2 -- don't plot mock EOS table
# # 3 -- plot mock EOS table
# limit = 2
# plt.figure(figsize=(11,5))
# for i, plotdata in enumerate(plotdata_list[:limit]):
#     # Sort the ray values by 'x' so there are no discontinuities in the line plot
#     srt = np.argsort(plotdata['x'])
#     # Exact values for this simulation
# #     if i == 0:
# #         plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), linestyle='-', color = "black", lw = lw, zorder=1000)
# #         plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), linestyle='-', color = "black", lw = lw, zorder=1000)
# #         plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), linestyle='-', color = "black", lw = lw, zorder=1000)
#     # Difference with numerical solution
#     # Plot them
#     plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), linestyle='', color = "red", marker=markers[i], fillstyle=fillstyle, lw = lw)
#     plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), linestyle='', color = "blue", marker=markers[i], fillstyle=fillstyle, lw = lw)
# #     plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), linestyle='', color = "green", marker=markers[i], fillstyle=fillstyle, lw = lw)

# # Make a nice plot
# plt.xlabel(r"$x$")
# plt.grid()
# # Nice legend:
# # Define custom legend handles and labels
# legend_handles = [
#     mpatches.Patch(color='green'),
#     mpatches.Patch(color='red'),
#     mpatches.Patch(color='blue'),
#     mlines.Line2D([], [], marker='^', color='black', linestyle='None', fillstyle="none"),
#     mlines.Line2D([], [], marker='v', color='black', linestyle='None', fillstyle="none")
# ]
# legend_labels = [r'$v$', r'$p/20$', r'$\rho/10$', 'Kastaun', 'NN assist']
# plt.legend(legend_handles, legend_labels, fontsize=12)
# plt.savefig(os.path.join(master_dir, "Plots/Final/shocktube_rho_kastaun_assist.pdf"), bbox_inches='tight')
# plt.show()

# %% [markdown]
# Reference:

# %%
# # Plot the data
# plotdata = plotdata_mock_table
# srt = np.argsort(plotdata['x'])
# plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['rho'][srt]/10), label='rho/10')
# plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['press'][srt]/20), label='P/20')
# plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['veloc1'][srt]), label='v')

# # Save the line plot
# plt.legend(loc='best')
# plt.title("Mock table")
# plt.grid()
# plt.show()

# %% [markdown]
# ## Diffs Kastaun & neural net vs analytic solution

# %%
plotdata_list = [plotdata_kastaun, plotdata_neuralnet]
labels = ["Kastaun", "NNC2P"]
colors = ["red", "blue", "green"]
markers = ["^", "v", "^"]
fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
small_delta = 0

plt.figure(figsize=(11, 3))

for i, plotdata in enumerate(plotdata_list):
    # Kastaun
    if i == 0:
        srt = kastaun_srt
    else:
        srt = neuralnet_srt
    x = np.array(plotdata['x'][srt])
    # Approximate vals:
    array = np.array([plotdata['rho']])[0] /10#/ 20
    # Get exact vals with interpolation
    exact = np.interp(x, exact_shocktube_x, exact_shocktube_rho)
    diffs = abs(array - exact)
    plt.plot(x, diffs, marker=markers[i], label = labels[i], color = colors[i], fillstyle=fillstyle, lw = lw)

# plt.plot(np.array(plotdata['x'][srt]), diffs_rho, "-", color="gray",lw=0.5)
# Make a nice plot
plt.ylabel(r"$\Delta\rho$")
plt.xlabel(r"$x$")
plt.yscale('log')
plt.xticks()
plt.yticks()
plt.grid()
plt.legend()
# plt.title("Smooth sine wave test")
# plt.ylim(1e-4 - small_delta, 1e-2 + small_delta)
plt.savefig(os.path.join(master_dir, "Plots/Final/shocktube_diffs.pdf"), bbox_inches='tight')
plt.show()

# %%
plotdata_list = [plotdata_kastaun, plotdata_neuralnet]
labels = ["Kastaun", "NNC2P"]
colors = ["red", "blue", "green"]
markers = ["^", "v", "^"]
fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
small_delta = 0

plt.figure(figsize=(11, 3))

for i, plotdata in enumerate(plotdata_list):
    # Kastaun
    if i == 0:
        srt = kastaun_srt
    else:
        srt = neuralnet_srt
    x = np.array(plotdata['x'][srt])
    # Approximate vals:
    array = np.array([plotdata['press']])[0] / 20
    # Get exact vals with interpolation
    exact = np.interp(x, exact_shocktube_x, exact_shocktube_press)
    diffs = abs(array - exact)
    plt.plot(x, diffs, marker=markers[i], label = labels[i], color = colors[i], fillstyle=fillstyle, lw = lw)

# plt.plot(np.array(plotdata['x'][srt]), diffs_rho, "-", color="gray",lw=0.5)
# Make a nice plot
plt.ylabel(r"$\Delta p$")
plt.xlabel(r"$x$")
plt.yscale('log')
plt.xticks()
plt.yticks()
plt.grid()
plt.legend()
# plt.title("Smooth sine wave test")
# plt.ylim(1e-4 - small_delta, 1e-2 + small_delta)
plt.savefig(os.path.join(master_dir, "Plots/Final/shocktube_diffs_press.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Diffs shocktube Kastaun and mock table

# %%
kastaun_check = kastaun_shock.ortho_ray(0, (0, 0))
plotdata_kastaun = kastaun_check
kastaun_srt = np.argsort(kastaun_check['x'])
kastaun_rho_check = np.array(kastaun_check['rho'][kastaun_srt])
kastaun_x = kastaun_check['x'][kastaun_srt]

mock_check = mock_table_shock.ortho_ray(0, (0, 0))
plotdata_mock = mock_check
mock_srt = np.argsort(mock_check['x'])
mock_rho_check = np.array(mock_check['rho'][mock_srt])
mock_x = mock_check['x'][mock_srt]

# Different lenghts, so resample:
# Determine the shorter array length
shorter_length = min(len(kastaun_rho_check), len(mock_rho_check))

# Resample the shorter array using linear interpolation
new_x = np.linspace(0, 1, shorter_length)

resampled_array1 = np.interp(new_x, kastaun_x, kastaun_rho_check)
resampled_array2 = np.interp(new_x, mock_x, mock_rho_check)

# Compute the absolute difference between the resampled arrays
diffs_kastaun_mock = np.abs(resampled_array1 - resampled_array2)
# diffs_kastaun_mock += sys.float_info.min

plt.figure(figsize=(7,5))
# plt.plot(np.array(mock_check['x'][srt]), diffs_kastaun_mock, linestyle='', marker="o", color="blue", label=r"|Kastaun - mock EOS table|", ms=6, fillstyle="none")
# plt.plot(np.array(mock_check['x'][srt]), diffs_kastaun_mock, "-", color="gray", lw=1)
# plt.plot(np.array(mock_check['x'][mock_srt]), mock_rho_check, linestyle='', marker="^", color="blue", label=r"Kastaun", ms=6, fillstyle="none")
# plt.plot(np.array(kastaun_check['x'][kastaun_srt]), kastaun_rho_check, linestyle='', marker="v", color="blue", label=r"mock EOS table", ms=6, fillstyle="none")
plt.plot(new_x, diffs_kastaun_mock, linestyle='', marker="o", color="blue", label=r"mock EOS table", ms=6, fillstyle="none")
plt.grid()
# plt.legend()
plt.xlabel(r"$x$")
plt.ylabel(r"$\Delta\rho$")
plt.yscale('log')
plt.savefig(os.path.join(master_dir, "Plots/Final/shock_diffs_mock_and_kastaun.pdf"), bbox_inches='tight')

plt.show()

# %%
plotdata_list = [plotdata_kastaun, plotdata_mock]
labels = ["Analytic EOS", "Mock table"]
colors = ["red", "blue", "green"]
markers = ["^", "v", "^"]
fillstyle = "none"
# ms=3
# lw=1
# alpha = 1
small_delta = 0

plt.figure(figsize=(7,5))

for i, plotdata in enumerate(plotdata_list):
    # Kastaun
    if i == 0:
        srt = kastaun_srt
    else:
        srt = mock_srt
    x = np.array(plotdata['x'][srt])
    # Approximate vals:
    array = np.array([plotdata['rho']])[0] /10 #/ 20
    # Get exact vals with interpolation
    exact = np.interp(x, exact_shocktube_x, exact_shocktube_rho)
    diffs = abs(array - exact)
    plt.plot(x, diffs, marker=markers[i], label = labels[i], color = colors[i], fillstyle=fillstyle, lw = lw)

# plt.plot(np.array(plotdata['x'][srt]), diffs_rho, "-", color="gray",lw=0.5)
# Make a nice plot
plt.ylabel(r"$\Delta\rho$")
plt.xlabel(r"$x$")
plt.yscale('log')
plt.xticks()
plt.yticks()
plt.grid()
plt.legend()
# plt.title("Smooth sine wave test")
# plt.ylim(1e-4 - small_delta, 1e-2 + small_delta)
plt.savefig(os.path.join(master_dir, "Plots/Final/shocktube_diffs_analytic_mock_table.pdf"), bbox_inches='tight')
plt.show()

# %%
print(f"{np.mean(diffs_kastaun_mock)}")

# %% [markdown]
# # Convergence plots

# %% [markdown]
# Directory location:

# %%
conv_wave_dir = os.path.join(master_dir, "Data/convergence_results/conv_wave")
conv_shock_dir = os.path.join(master_dir, "Data/convergence_results/conv_shocktube")

# %% [markdown]
# The grid sizes that were used:

# %%
grid_sizes = [100, 200, 400, 800, 1600, 3200]

# %% [markdown]
# ## Auxiliary method to get error

# %% [markdown]
# The analytic solution to the problem:

# %% [markdown]
# TODO - get the neural net error on the prims for a very large sample?

# %%
A = 0.2
v0 = 0.2
theta = 0.0

def rho_sol_pt(x,y,t):
    return 1.0 + A * np.sin(2.0 * np.pi * ( ( x * np.cos(theta) + y * np.sin(theta) ) - ( v0 * np.cos(theta) ) * t ) )

rho_sol = np.vectorize(rho_sol_pt)

def gamma(field, data):
    return  np.sqrt( 1.0 + (data['W_vel1']**2) )
def veloc1(field, data):
    return data['W_vel1'] / data['gamma']

# %% [markdown]
# Auxiliary method to find the numerical error from a simulation file

# %%
def get_all_errors(dat, grid_sizes, var_names = ["rho", "eps", "press", "veloc1"], exact_sol = rho_sol, T_final=5.0, which="sine"):
    """
    Returns a list of errors for different grids
    
    Dat: list of loaded data files to get the values of simulations from.
    """
    # Initialize empty dicts:
    # each dict: key for the var names, every value has errors for increasing grid size
    l1_dict = {}
    linfty_dict = {}
    for var in var_names:
        l1_dict[var] = []
        linfty_dict[var] = []
    
    # Iterate over each var name
    for i, grid_size in enumerate(grid_sizes):
        this_grid_data = dat[i]
        for var in var_names:
            if which == "shocktube":
                l1, linfty = compute_error_shock(this_grid_data, var_name=var, exact_sol=exact_sol, T_final=T_final)
                l1_dict[var].append(l1)
                linfty_dict[var].append(linfty)
            else:
                l1, linfty = compute_error_sine(this_grid_data, var_name=var, exact_sol=exact_sol, T_final=T_final)
                l1_dict[var].append(l1)
                linfty_dict[var].append(linfty)
    return l1_dict, linfty_dict

def compute_error_sine(dat, var_name = "rho", exact_sol = rho_sol, T_final=5.0):
    """Computes error based on the exact sine wave"""
    # Get the plotdata
    plotdata   = dat.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    # Get exact values and numerical solution values
    rho_vals = np.array(exact_sol(np.array(plotdata['x'][srt]), 0.0, T_final))
    if var_name == "rho":
        exact_vals = rho_vals
    elif var_name == "veloc1":
        exact_vals = v0
    elif var_name == "press":
        exact_vals = 1
    elif var_name == "eps":
        exact_vals = (3/2) * (1/rho_vals)
    else:
        print("Not recognized")
        return 0, 0
    num_vals = np.array(plotdata[var_name][srt])
    # Get the differences
    diffs = abs(num_vals - exact_vals)
    
    # Append errors
    #l1 = np.mean(diffs)  # replaced by delta_N!
    l1 = np.sum(diffs)/np.sum(abs(exact_vals))
    # ^ this is delta_N, defined in Gmunu parallel, grid-adaptive,... paper!!!
    linfty = np.max(diffs)
    
    return l1, linfty

def compute_error_shock(dat, var_name = "rho", exact_sol = rho_sol, T_final=5.0):
    """Computes error based on the shocktube problem"""
    # Get the plotdata
    plotdata   = dat.ortho_ray(0, (0, 0))
    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['x'])
    x = np.array(plotdata['x'])[srt]
    # Take rho by default!!!
    exact_vals = np.interp(x, exact_shocktube_x, exact_shocktube_rho)
#     if var_name == "rho":
#         exact_vals = rho_vals
#     elif var_name == "veloc1":
#         exact_vals = v0
#     elif var_name == "press":
#         exact_vals = 1
#     elif var_name == "eps":
#         exact_vals = (3/2) * (1/rho_vals)
#     else:
#         print("Not recognized")
#         return 0, 0
    num_vals = np.array(plotdata[var_name][srt]) / 10
    # Get the differences
    diffs = abs(num_vals - exact_vals)
    
    # Append errors
    #l1 = np.mean(diffs)  # replaced by delta_N!
    l1 = np.sum(diffs)/np.sum(abs(exact_vals))
    # ^ this is delta_N, defined in Gmunu parallel, grid-adaptive,... paper!!!
    linfty = np.max(diffs)
    
    return l1, linfty

# %% [markdown]
# ## Sine wave

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
kastaun_data = []
neuralnet_data = []
for grid_size in grid_sizes:
    # Kastaun:
    fname = os.path.join(conv_wave_dir, f"kastaun_{grid_size}.dat")
    dat = yt.load(fname)
    dat.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    dat.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    kastaun_data.append(dat)
    # Neuralnet:
    fname = os.path.join(conv_wave_dir, f"neuralnet_{grid_size}.dat")
    dat = yt.load(fname)
    dat.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    dat.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    neuralnet_data.append(dat)
# Out:
# yt : [INFO     ] 2023-06-06 08:32:36,324 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:36,324 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-06-06 08:32:36,332 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:36,335 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:36,336 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:36,365 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:36,888 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:36,888 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-06-06 08:32:36,888 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:36,896 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:36,896 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:36,921 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:37,448 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:37,448 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-06-06 08:32:37,456 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:37,456 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:37,460 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:37,489 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:38,159 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:38,167 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-06-06 08:32:38,171 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:38,172 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:38,175 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:38,218 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:38,951 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:38,953 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-06-06 08:32:38,953 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:38,953 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:38,964 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:39,027 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:39,680 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:39,684 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-06-06 08:32:39,691 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:39,691 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:39,697 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:39,771 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:40,523 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:40,523 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-06-06 08:32:40,523 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:40,534 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:40,536 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:40,618 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:41,341 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:41,341 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-06-06 08:32:41,350 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:41,353 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:41,357 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:41,439 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:42,093 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:42,093 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-06-06 08:32:42,100 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:42,105 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:42,112 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:42,272 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:43,262 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:43,262 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-06-06 08:32:43,271 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:43,272 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:43,279 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:44,190 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:44,971 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:44,971 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-06-06 08:32:44,971 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:44,971 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:44,979 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:45,255 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:32:45,760 Parameters: current_time              = 5.0
# yt : [INFO     ] 2023-06-06 08:32:45,760 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-06-06 08:32:45,760 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:32:45,760 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:32:45,768 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:32:46,045 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# Compute the errors and convergence rates

# %%
kastaun_l1, kastaun_linfty = get_all_errors(kastaun_data, grid_sizes)
neuralnet_l1, neuralnet_linfty = get_all_errors(neuralnet_data, grid_sizes)
# Out:
# yt : [WARNING  ] 2023-06-06 08:33:05,967 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:05,977 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:06,215 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:06,219 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:06,584 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:06,592 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:06,998 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:07,006 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:07,653 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:07,661 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:08,923 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:08,930 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:08,996 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:08,997 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,077 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,087 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,286 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,294 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,681 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:09,684 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:10,248 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:10,256 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:11,276 Field ('amrvac', 'gamma') was added without specifying units or dimensions, auto setting units to dimensionless
# yt : [WARNING  ] 2023-06-06 08:33:11,284 Field ('amrvac', 'veloc1') was added without specifying units or dimensions, auto setting units to dimensionless

# %%
kastaun_l1
# Out:
# {'rho': [0.00655815126601933,
#   0.0018072405985626904,
#   0.000494932394563152,
#   0.00013528772590231663,
#   3.594577576439384e-05,
#   9.395738620550133e-06],
#  'eps': [0.006955360618438373,
#   0.0019434348522395332,
#   0.0005342318163101429,
#   0.00014635328930475618,
#   3.895954694148686e-05,
#   1.0197186456877594e-05],
#  'press': [7.907896559800065e-12,
#   3.1102231901058985e-11,
#   1.2822798378664402e-10,
#   2.4350144123275186e-10,
#   5.161417959698156e-10,
#   1.8488390818305334e-09],
#  'veloc1': [3.5790814756353484e-13,
#   5.315192730392937e-13,
#   2.143563104795021e-12,
#   6.210892911084898e-11,
#   4.02418098843782e-10,
#   1.6155617121871302e-09]}

# %%
convergence_rates = []
for data in [kastaun_l1, neuralnet_l1]:
    rates = []
    for i in range(1, len(grid_sizes)):
        value = np.log2(data["rho"][i-1]/data["rho"][i])
        rates.append(value)
    convergence_rates.append(rates)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize=(11,3))
alph=1
ax1, ax2 = axs
color_dict = {"press": "blue", "rho": "orange", "eps": "green", "veloc1": "red"}
markers = ["^", "v"] # kastaun, neuralnet

l1_values = [kastaun_l1, neuralnet_l1]
linfty_values = [kastaun_linfty, neuralnet_linfty]

for var in color_dict.keys():
    for i in range(len(l1_values)):
        # L1 rate
        ax1.plot(grid_sizes, l1_values[i][var], linestyle='', marker=markers[i], color = color_dict[var], alpha=alph, fillstyle="none")
        ax1.set_ylabel(r"$(\Delta p)_{\ell_1}$")
        
        ax2.plot(grid_sizes, linfty_values[i][var], linestyle='', marker=markers[i], color = color_dict[var], alpha=alph, fillstyle="none")
        ax2.set_ylabel(r"$(\Delta p)_{\ell_\infty}$")

for ax in axs:
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel("Grid size")
    ax.set_xticks(grid_sizes, labels=grid_sizes)
    ax.grid()
#     ax.legend()
# plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_wave.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Compare convergence rates (uses rho only)!

# %% [markdown]
# Convergence rate: see Gmunu paper ("parallel, grid adaptive,...")

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize=(11,3))
alph=1
ms = 10
ax1, ax2 = axs
color_dict = {"press": "blue", "rho": "orange", "eps": "green", "veloc1": "red"}
markers = ["^", "v"] # kastaun, neuralnet
labels = ["Kastaun", "NNC2P"]

l1_values = [kastaun_l1, neuralnet_l1]
linfty_values = [kastaun_linfty, neuralnet_linfty]

for i in range(len(l1_values)):
    # delta N
    ax1.plot(grid_sizes, l1_values[i]["rho"], linestyle='', marker=markers[i], ms=ms, color = colors[i], label=labels[i], alpha=alph, fillstyle="none")
    ax1.set_ylabel(r"$\delta_N$")
    # Line for ideal scaling
#     if i == 0:
#         line_x = np.arange(grid_sizes[0], grid_sizes[-1], 0.01)
#         y0 = 0.000001
#         line_y = y0 + (line_x - grid_sizes[0])**(-2)
#         ax1.plot(line_x, line_y, "--", color="black")

    # R_N
    ax2.plot(grid_sizes[1:], convergence_rates[i], linestyle='', marker=markers[i], ms=ms, color = colors[i], alpha=alph, fillstyle="none")
    ax2.set_ylabel(r"$R_N$")

for ax in axs:
    ax.set_xscale('log')
    ax.set_xlabel(r"$N$")
    ax.set_xticks(grid_sizes, labels=grid_sizes)
    ax.grid()
ax1.legend()
ax1.set_yscale('log')
plt.savefig("../Plots/Final/convergence_runs_wave.pdf", bbox_inches='tight')
plt.show()

# %%
# alph=1
# markers = ["^", "v"] # kastaun, neuralnet
# colors = ["red", "blue"]
# labels = ["Kastaun", "NNC2P"]

# l1_values = [kastaun_l1, neuralnet_l1]

# for i in range(len(l1_values)):
#     # L1 rate
#     plt.plot(grid_sizes, l1_values[i]["rho"], linestyle='', marker=markers[i], color = colors[i], label=labels[i], alpha=alph, fillstyle="none")

# plt.xscale('log')
# plt.yscale('log')
# plt.xlabel("Grid size $N$")
# plt.ylabel(r"$\delta_N$")
# plt.xticks(grid_sizes, labels=grid_sizes)
# plt.grid()
# plt.legend()
# # plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_wave.pdf"), bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Shocktube

# %% [markdown]
# Read in the Kastaun and neural net sine waves

# %%
kastaun_data = []
neuralnet_data = []
for grid_size in grid_sizes:
    # Kastaun:
    fname = os.path.join(conv_shock_dir, f"kastaun_{grid_size}.dat")
    dat = yt.load(fname)
    dat.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    dat.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    kastaun_data.append(dat)
    # Neuralnet:
    fname = os.path.join(conv_shock_dir, f"neuralnet_{grid_size}.dat")
    dat = yt.load(fname)
    dat.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    dat.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    neuralnet_data.append(dat)
# Out:
# yt : [INFO     ] 2023-06-06 08:34:39,748 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:39,748 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-06-06 08:34:39,756 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:39,756 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:39,764 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:39,798 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:40,367 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:40,367 Parameters: domain_dimensions         = [100   1   1]
# yt : [INFO     ] 2023-06-06 08:34:40,375 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:40,375 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:40,383 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:40,425 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:41,023 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:41,034 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-06-06 08:34:41,037 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:41,039 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:41,039 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:41,088 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:41,663 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:41,671 Parameters: domain_dimensions         = [200   1   1]
# yt : [INFO     ] 2023-06-06 08:34:41,671 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:41,671 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:41,688 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:41,741 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:42,771 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:42,780 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-06-06 08:34:42,786 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:42,786 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:42,796 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:42,929 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:43,757 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:43,765 Parameters: domain_dimensions         = [400   1   1]
# yt : [INFO     ] 2023-06-06 08:34:43,773 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:43,783 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:43,788 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:44,877 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:45,851 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:45,859 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-06-06 08:34:45,868 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:45,874 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:45,880 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:46,005 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:46,574 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:46,576 Parameters: domain_dimensions         = [800   1   1]
# yt : [INFO     ] 2023-06-06 08:34:46,578 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:46,581 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:46,585 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:46,664 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:47,227 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:47,227 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-06-06 08:34:47,227 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:47,235 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:47,235 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:47,366 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:48,017 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:48,020 Parameters: domain_dimensions         = [1600    1    1]
# yt : [INFO     ] 2023-06-06 08:34:48,020 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:48,020 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:48,032 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:48,213 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:49,097 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:49,101 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-06-06 08:34:49,104 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:49,113 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:49,118 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:49,478 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2023-06-06 08:34:50,216 Parameters: current_time              = 0.4
# yt : [INFO     ] 2023-06-06 08:34:50,222 Parameters: domain_dimensions         = [3200    1    1]
# yt : [INFO     ] 2023-06-06 08:34:50,222 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:34:50,229 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:34:50,229 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:34:50,572 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# Compute the errors and convergence rates

# %%
kastaun_l1, kastaun_linfty = get_all_errors(kastaun_data, grid_sizes, var_names = ["rho"], which="shocktube")
neuralnet_l1, neuralnet_linfty = get_all_errors(neuralnet_data, grid_sizes, var_names = ["rho"], which="shocktube")

# %%
convergence_rates = []
for data in [kastaun_l1, neuralnet_l1]:
    rates = []
    for i in range(1, len(grid_sizes)):
        value = np.log2(data["rho"][i-1]/data["rho"][i])
        rates.append(value)
    convergence_rates.append(rates)

# %%
# for var in color_dict.keys():
#     for i in range(len(l1_values)):
#         # L1 rate
#         ax1.plot(grid_sizes, l1_values[i][var], linestyle='', marker=markers[i], color = color_dict[var], alpha=alph, fillstyle="none")
#         ax1.set_ylabel(r"$(\Delta p)_{\ell_1}$")
        
#         ax2.plot(grid_sizes, linfty_values[i][var], linestyle='', marker=markers[i], color = color_dict[var], alpha=alph, fillstyle="none")
#         ax2.set_ylabel(r"$(\Delta p)_{\ell_\infty}$")

# for ax in axs:
#     ax.set_xscale('log')
#     ax.set_yscale('log')
#     ax.set_xlabel("Grid size")
#     ax.set_xticks(grid_sizes, labels=grid_sizes)
#     ax.grid()
#     ax.legend()
# plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_shocktube.pdf"), bbox_inches='tight')
# plt.show()

# %% [markdown]
# Ugly plot, not going to discuss it in report

# %%
# fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize=(11,3))
# alph=1
# ms = 10
# ax1, ax2 = axs
# color_dict = {"press": "blue", "rho": "orange", "eps": "green", "veloc1": "red"}
# markers = ["^", "v"] # kastaun, neuralnet
# labels = ["Kastaun", "NNC2P"]

# l1_values = [kastaun_l1, neuralnet_l1]
# linfty_values = [kastaun_linfty, neuralnet_linfty]

# for i in range(len(l1_values)):
#     # delta N
#     ax1.plot(grid_sizes, l1_values[i]["rho"], linestyle='', marker=markers[i], ms=ms, color = colors[i], label=labels[i], alpha=alph, fillstyle="none")
#     ax1.set_ylabel(r"$\delta_N$")
#     # Line for ideal scaling
# #     if i == 0:
# #         line_x = np.arange(grid_sizes[0], grid_sizes[-1], 0.01)
# #         y0 = 0.000001
# #         line_y = y0 + (line_x - grid_sizes[0])**(-2)
# #         ax1.plot(line_x, line_y, "--", color="black")

#     # R_N
#     ax2.plot(grid_sizes[1:], convergence_rates[i], linestyle='', marker=markers[i], ms=ms, color = colors[i], alpha=alph, fillstyle="none")
#     ax2.set_ylabel(r"$R_N$")

# for ax in axs:
#     ax.set_xscale('log')
#     ax.set_xlabel(r"$N$")
#     ax.set_xticks(grid_sizes, labels=grid_sizes)
#     ax.grid()
# ax1.legend()
# ax1.set_yscale('log')
# plt.savefig("../Plots/Final/convergence_runs_shocktube.pdf", bbox_inches='tight')
# plt.show()

# %%
# alph=1
# markers = ["^", "v"] # kastaun, neuralnet
# colors = ["red", "blue"]
# labels = ["Kastaun", "NNC2P"]

# l1_values = [kastaun_l1, neuralnet_l1]

# for i in range(len(l1_values)):
#     # L1 rate
#     plt.plot(grid_sizes, l1_values[i]["rho"], linestyle='', marker=markers[i], color = colors[i], label=labels[i], alpha=alph, fillstyle="none")

# plt.xscale('log')
# plt.yscale('log')
# plt.xlabel("Grid size $N$")
# plt.ylabel(r"$\delta_N$")
# plt.xticks(grid_sizes, labels=grid_sizes)
# plt.grid()
# plt.legend()
# # plt.savefig(os.path.join(master_dir, "Plots/Final_plots/convergence_runs_wave.pdf"), bbox_inches='tight')
# plt.show()

# %% [markdown]
# # Timings

# %% [markdown]
# ## Smooth sine wave:

# %%
def get_average_timing(timings):
    # Roll, get next in position of current
    rolled = np.roll(timings, -1)
    # Difference is nb of iterations per sec:
    its = rolled - timings
    # Drop final column
    its = its[:, 0:-1]
    return np.mean(its)

# %% [markdown]
# Neuralnet:

# %%
wave_timings_neuralnet = np.array([[0, 44, 98, 151, 204], [0, 53, 106, 159, 212], [0, 53, 106, 158, 210], [0, 53, 106, 159, 212], [0, 53, 107, 160, 213], [0, 53, 106, 159, 212]])
speed_neuralnet = get_average_timing(wave_timings_neuralnet)
ttc_neuralnet = np.round(np.mean([5.096, 5.774, 5.028, 5.089, 5.068, 5.156, 5.353, 5.162, 5.074, 5.363]), 4)
print(f"For neuralnet: speed: {speed_neuralnet}. TTC: {ttc_neuralnet}")
# Out:
# For neuralnet: speed: 52.625. TTC: 5.2163

# %% [markdown]
# Kastaun: computed differently since this completes in less than a second:

# %%
wave_timings_kastaun = np.array([0.102, 0.101, 0.103, 0.102, 0.101, 0.100])
ttc_kastaun = np.mean(wave_timings_kastaun)
speed_kastaun = np.mean(260/wave_timings_kastaun)
print(f"For Kastaun: speed: {np.round(speed_kastaun, 2)}. TTC: {np.round(ttc_kastaun, 4)}")
# Out:
# For Kastaun: speed: 2561.8. TTC: 0.1015

# %% [markdown]
# Mock analytic EOS table: same

# %%
wave_timings_mock = np.array([251, 230, 266, 257, 40, 177, 240, 189, 176, 273, 252, 271])
ttc_mock = np.round(np.mean([1.404, 1.025, 1.586, 1.298, 1.081, 1.432, 1.229, 1.083, 1.053]), 4)
speed_mock = np.round(np.mean(wave_timings_mock), 2)
print(f"For mock: speed: {speed_mock}. TTC: {ttc_mock}")
# Out:
# For mock: speed: 218.5. TTC: 1.2434

# %% [markdown]
# NN assist: same

# %%
wave_timings_assist = np.array([0.104, 0.097, 0.099, 0.096, 0.097, 0.103, 0.098, 0.098, 0.096, 0.097])
speed_assist = np.mean(312/wave_timings_assist)
print(f"For Kastaun: {speed_assist}")
# Out:
# For Kastaun: 3169.7472839965367

# %%
my_dict = {"Method": ["Kastaun", "Neuralnet", "Mock table"], 
           "Speed (it/s)": np.round([speed_kastaun, speed_neuralnet, speed_mock], 2),
           "TTC (s)": [ttc_kastaun, ttc_neuralnet, ttc_mock]}

# %% [markdown]
# Now, add the analysis based on TTC

# %%
df = pd.DataFrame.from_dict(my_dict)
df = df.sort_values(by = "Speed (it/s)", ascending=False)

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &      Method &  Speed (it/s) &  TTC (s) \\
# \midrule
# 0 &     Kastaun &       2561.80 &   0.1015 \\
# 2 &  Mock table &        218.50 &   1.2434 \\
# 1 &   Neuralnet &         52.62 &   5.2163 \\
# \bottomrule
# \end{tabular}
# C:\Users\thibe\AppData\Local\Temp\ipykernel_18248\2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %% [markdown]
# ## Shocktube results:

# %%
shock_timings_kastaun = np.array([576, 625, 628, 626, 625, 628, 626, 611, 627, 576, 621]) # its/s
shock_ttc_kastaun = np.array([1.888, 1.758, 1.746, 1.748, 1.743, 1.747, 1.758])

shock_timings_neuralnet = np.array([[0, 55, 93, 133, 171, 204], [0, 54, 91, 132, 170, 203], [0, 52, 86, 125, 163, 196]])
shock_ttc_neuralnet = np.array([37.239, 35.628, 36.074])

shock_timings_mock = np.array([[0, 224, 376, 496, 598, 701, 821, 934], [0, 234, 362, 483, 615, 714, 831, 949], [0, 224, 355, 465, 575, 688, 802, 910]])
shock_ttc_mock = np.array([7.567, 7.534, 7.777])

# %% [markdown]
# Generate df from it

# %%
my_dict = {"Method": ["Kastaun", "Neuralnet", "Mock table"], 
           "Speed (it/s)": np.round([np.mean(shock_timings_kastaun), get_average_timing(shock_timings_neuralnet), get_average_timing(shock_timings_mock)], 2),
           "TTC (s)": np.round([np.mean(shock_ttc_kastaun), np.mean(shock_ttc_neuralnet), np.mean(shock_ttc_mock)], 2)}

# %%
df = pd.DataFrame.from_dict(my_dict)
df = df.sort_values(by = "Speed (it/s)", ascending=False)

# %%
df
# Out:
#        Method  Speed (it/s)  TTC (s)
# 0     Kastaun        615.36     1.77
# 2  Mock table        133.00     7.63
# 1   Neuralnet         40.20    36.31

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &      Method &  Speed (it/s) &  TTC (s) \\
# \midrule
# 0 &     Kastaun &        615.36 &     1.77 \\
# 2 &  Mock table &        133.00 &     7.63 \\
# 1 &   Neuralnet &         40.20 &    36.31 \\
# \bottomrule
# \end{tabular}
# C:\Users\thibe\AppData\Local\Temp\ipykernel_18248\2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %% [markdown]
# # NS simulation

# %%
# fname = os.path.normpath(os.path.join(master_dir, "/Data/NS simulations/nntabeos/output0004.dat"))
fname = os.path.abspath("D:/Coding/master-thesis-AI/Data/NS simulations/nntabeos/output0004.dat")
nneos = yt.load(fname)
fname = "D:/Coding/master-thesis-AI/Data/NS simulations/LT eos/output0004.dat"
# fname = os.path.normpath(os.path.join(master_dir, "Data/NS simulations/LT tabeos/output00004.dat"))
tabeos = yt.load(fname)

# Final time of simulation 
T_final = float(nneos.current_time)
# Additional preprocessing - see Gmunu for the source of this
for sol in [nneos, tabeos]:
    # Add gamma and veloc1
    sol.add_field(('amrvac','gamma'),  function=gamma,  sampling_type='cell')
    sol.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
# Get the plotdata
plotdata_nneos  = nneos.ortho_ray(0, (0, 0))
plotdata_tabeos = tabeos.ortho_ray(0, (0, 0))
# Out:
# yt : [INFO     ] 2023-06-06 08:42:56,014 Parameters: current_time              = 812.5774454205114
# yt : [INFO     ] 2023-06-06 08:42:56,014 Parameters: domain_dimensions         = [256   1   1]
# yt : [INFO     ] 2023-06-06 08:42:56,026 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:42:56,031 Parameters: domain_right_edge         = [400.   1.   1.]
# yt : [INFO     ] 2023-06-06 08:42:56,031 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-06 08:42:56,246 Parameters: current_time              = 813.1483035457605
# yt : [INFO     ] 2023-06-06 08:42:56,246 Parameters: domain_dimensions         = [256   1   1]
# yt : [INFO     ] 2023-06-06 08:42:56,246 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:42:56,252 Parameters: domain_right_edge         = [400.   1.   1.]
# yt : [INFO     ] 2023-06-06 08:42:56,260 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:42:56,285 e not found and no parfile passed, can not set thermal_pressure.

# %% [markdown]
# Prepare for the plot:

# %%
srt = np.argsort(plotdata_nneos['r'])
length_gf = 6.77140812e-06*1.0e5 # to km
rho_gf = 1.61930347e-18
press_gf = 1.80171810e-39
eps_gf = 1.11265006e-21

x_min = plotdata_nneos['r'][0]/length_gf
x_max = plotdata_nneos['r'][-1]/length_gf

# %%
solutions = [nneos, tabeos]
labels = ["Interpolation", "NNEOS"]
colors = ["red", "blue", "purple"]
markers = ["^", "v", "^"]
fillstyle = "none"
ms=3
lw=1
alpha = 1

fig, axs = plt.subplots(1, 2, figsize=(11,3))
(ax1, ax2) = axs

for i, solution in enumerate(solutions):
    # cutting the x-axis through the y=0,z=0 
    plotdata = solution.ortho_ray(0, (0, 0))

    # Sort the ray values by 'x' so there are no discontinuities in the line plot
    srt = np.argsort(plotdata['r'])
    
    ax1.plot(np.array(plotdata['r'][srt])/length_gf, np.array(plotdata['rho'][srt])/rho_gf, linestyle='-', color=colors[i], fillstyle=fillstyle, ms = ms, label=labels[i])
    ax2.plot(np.array(plotdata['r'][srt])/length_gf, np.array(plotdata['eps'][srt])/eps_gf, linestyle='-', color=colors[i], fillstyle=fillstyle, ms = ms, label=labels[i]) 

    # Make a nice plot
ax1.set_ylabel(r"$\rho \ \rm{[ g / cm^3 ]}$ ")
ax2.set_ylabel(r"$\varepsilon \ [\rm{erg} / \rm{g} ]$")
for ax in axs:
    ax.set_xlabel(r"$r$")
    ax.set_xlabel(r"$r$")
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.grid()
ax1.legend()
plt.savefig("../Plots/Final/NNEOS_20_20_relu_NS.pdf", bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Look at the diffs

# %%
# solutions = [nneos, tabeos]
# labels = ["Interpolation", "NNEOS"]
# colors = ["red", "blue", "purple"]
# markers = ["^", "v", "^"]
# fillstyle = "none"
# ms=3
# lw=1
# alpha = 1

# fig, axs = plt.subplots(1, 2, figsize=(11,3))
# (ax1, ax2) = axs

# # Sort the ray values by 'x' so there are no discontinuities in the line plot
# srt = np.argsort(plotdata['r'])

# diffs_press = abs(np.array(plotdata_nneos['rho'][srt]) - np.array(plotdata_tabeos['rho'][srt]))
# diffs_eps = abs(np.array(plotdata_nneos['eps'][srt]) - np.array(plotdata_tabeos['eps'][srt]))

# ax1.plot(np.array(plotdata['r'][srt])/length_gf, diffs_press, linestyle='-', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i])
# ax2.plot(np.array(plotdata['r'][srt])/length_gf, diffs_eps, linestyle='-', color=colors[i], marker=markers[i], fillstyle=fillstyle, ms = ms, label=labels[i]) 

#     # Make a nice plot
# # ax1.set_ylabel(r"$\rho \\rm{[ g / cm^3 ]}$ ")
# # ax2.set_ylabel(r"$\varepsilon$")
# for ax in axs:
#     ax.set_xlabel(r"$x$")
#     ax.set_xlabel(r"$x$")
#     ax.set_yscale('log')
#     ax.set_xscale('log')
#     ax.grid()
# ax1.legend()
# plt.show()

# %% [markdown]
# Look at differences?

# %%
# fname = os.path.normpath(os.path.join(master_dir, "/Data/NS simulations/nntabeos/output0004.dat"))
fname = os.path.abspath("D:/Coding/master-thesis-AI/Data/NS simulations/nntabeos/comparison_prs.dat")
comparison_prs = np.loadtxt(fname)
comparison_prs.shape
# Out:
# (538685, 3)

# %%
import seaborn as sn

# %%
plt.figure(figsize=(11,3))
rel_prs_errors = comparison_prs[0:-1:10, 2]/comparison_prs[0:-1:10, 0]
sn.kdeplot(rel_prs_errors, color="blue", fill=True)
plt.xscale('log')
plt.xlabel(r"$\frac{|p - \hat{p}|}{p}$", fontsize = fs_labels + 4)
plt.show()

# %%
# plt.figure(figsize=(11,3))
# plt.violinplot(rel_prs_errors, vert=False)
# plt.xscale('log')
# plt.show()

# %% [markdown]
# # GRMHD

# %% [markdown]
# Plot the Alfven wave for the thesis

# %%
def veloc2(field, data):
    return data['W_vel2'] / data['gamma']

# %%
fname = os.path.join(master_dir, "Data/alfven_wave.dat")
wave = yt.load(fname)
fname = os.path.join(master_dir, "Data/alfven_wave_ic.dat")
ic = yt.load(fname)

# Final time of simulation 
T_final = float(wave.current_time)
# Additional preprocessing - see Gmunu for the source of this
for w in [wave, ic]:
    w.add_field(('amrvac','gamma'), function=gamma, sampling_type='cell')
    w.add_field(('amrvac','veloc1'), function=veloc1, sampling_type='cell')
    w.add_field(('amrvac','veloc2'), function=veloc2, sampling_type='cell')
# Get the plotdata
plotdata_alfven    = wave.ortho_ray(0, (0, 0))
plotdata_alfven_ic = ic.ortho_ray(0, (0, 0))
# Out:
# yt : [INFO     ] 2023-06-06 08:56:20,691 Parameters: current_time              = 10.0
# yt : [INFO     ] 2023-06-06 08:56:20,699 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 08:56:20,708 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:56:20,708 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:56:20,716 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-06-06 08:56:21,017 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-06-06 08:56:21,020 Parameters: domain_dimensions         = [128   1   1]
# yt : [INFO     ] 2023-06-06 08:56:21,023 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-06 08:56:21,023 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-06 08:56:21,031 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2023-06-06 08:56:21,065 e not found and no parfile passed, can not set thermal_pressure.

# %%
plt.figure(figsize=(9, 4))
labels = [r"$t = 0$", r"$t = 2$"]
colors = ["red", "blue"]
markers = ["^", "v"]

for i, plotdata in enumerate([plotdata_alfven_ic, plotdata_alfven]):
    srt = np.argsort(plotdata['x'])
    plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['Bvec3'][srt]), color = colors[i], marker=markers[i], fillstyle="none", label = labels[i])

# make the plot nice
plt.xlabel('$x$')
plt.ylabel('$B_z$')
plt.xlim(0, 1)
plt.xticks()
plt.yticks()
plt.legend(loc='best')
plt.grid()
plt.savefig('../Plots/Final/alfven.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Diffs

# %% [markdown]
# Not really interesting to discuss - we are still relying on Kastaun, so guaranteed accuracy!

# %%
# for i, plotdata in enumerate([plotdata_alfven_ic, plotdata_alfven]):

# ic_srt = np.argsort(plotdata_alfven_ic['x'])
# ic_Bz = np.array(plotdata['Bvec3'][srt]
# # plt.plot(np.array(plotdata['x'][srt]), np.array(plotdata['Bvec3'][srt]), color = colors[i], marker=markers[i], fillstyle="none", label = labels[i])

# %% [markdown]
# ## Counts for Brent method

# %% [markdown]
# Quick check of range of mu.dat

# %%
mu_vals = np.loadtxt("../Data/alfven_mu.dat")

# %%
print(np.min(mu_vals), np.max(mu_vals))
# Out:
# 0.3848662047489834 0.3849588941161483

# %% [markdown]
# ## Quick: timing NN assist GRHD

# %%
timings = np.array([0.153, 0.231, 0.153, 0.149, 0.153, 0.156, 0.155])
speed = 310/np.mean(timings)
ttc = np.mean(timings)
print(f"Speed: {speed}, ttc: {ttc}")
# Out:
# Speed: 1886.95652173913, ttc: 0.1642857142857143
