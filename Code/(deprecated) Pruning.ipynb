# %% [markdown]
# %%latex
# \tableofcontents

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300
import random
import csv
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor 
import matplotlib.cm as cm

# %% [markdown]
# # Introduction

# %% [markdown]
# We have trained model which is succesful in the C2P conversion, and this neural network is called NNC2Pv0. Naturally, we want to improve on these methods. One possibility is pruning the neural network: if we have less connections and neurons, we are more likely

# %% [markdown]
# # Generating training data

# %%
# Define the three functions determining the output
def eos(rho, eps, Gamma = 5/3):
    """Computes the analytical gamma law EOS from rho and epsilon"""
    return (Gamma - 1) * rho * eps

def h(rho, eps, v):
    """Enthalpy"""
    p = eos(rho, eps)
    return 1 + eps + p/rho

def W(rho, eps, v):
    """Lorentz factor. Here, in 1D so v = v_x"""
    return (1-v**2)**(-1/2)

def D(rho, eps, v):
    """See eq 2 paper"""
    return rho*W(rho, eps, v)

def S(rho, eps, v):
    """See eq2 paper. Note: 1D only for now."""
    return rho*h(rho, eps, v)*((W(rho, eps, v))**2)*v

def tau(rho, eps, v):
    """See eq2 paper."""
    return rho*(h(rho, eps, v))*((W(rho, eps, v))**2) - eos(rho, eps) - D(rho, eps, v)

# %% [markdown]
# We generate data as follows. We create a training set by randomly sampling as follows:
# - $\rho \in (0, 10.1)$,
# - $\epsilon \in (0, 2.02)$,
# - $v_x \in (0, 0.721)$.

# %%
# Define ranges of parameters to be sampled (see paper Section 2.1)
rho_min = 0
rho_max = 10.1
eps_min = 0
eps_max = 2.02
v_min = 0
v_max = 0.721

# %% [markdown]
# Note: the code in comment below was used to generate the data. It has now been saved separately in a folder called "data".

# %%
# number_of_datapoints = 10000
# data = []

# for i in range(number_of_datapoints):
#     rho = random.uniform(rho_min, rho_max)
#     eps = random.uniform(eps_min, eps_max)
#     v     = random.uniform(v_min, v_max)
    
#     p               = eos(rho, eps)
#     Dvalue    = D(rho, eps, v)
#     Svalue     = S(rho, eps, v)
#     tauvalue = tau(rho, eps, v)
    
#     new_row = [rho, eps, v, p, Dvalue, Svalue, tauvalue]
    
#     data.append(new_row)

# %% [markdown]
# Save the data in a csv file:

# %%
# header = ['rho', 'eps', 'v', 'p', 'D', 'S', 'tau']

# with open('data/NNC2P_data_test.csv', 'w', newline = '') as file:
#     writer = csv.writer(file)
#     # write header
#     writer.writerow(header)
#     # write data
#     writer.writerows(data)

# %%
# Import data
data_train = pd.read_csv("data/NNC2P_data_train.csv")
data_test = pd.read_csv("data/NNC2P_data_test.csv")
print("The training data has " + str(len(data_train)) + " instances")
print("The test data has " + str(len(data_test)) + " instances")
data_train

# %% [markdown]
# # Getting data into PyTorch's DataLoader

# %% [markdown]
# Below: `all_data` is of the type $(\rho, \epsilon, v, p, D, S_x, \tau)$ as generated above.

# %%
class CustomDataset(Dataset):
    """See PyTorch tutorial: the following three methods HAVE to be implemented"""
    
    def __init__(self, all_data, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        
        # Separate features (rho and eps) from the labels (p, chi, kappa)
        # (see above to get how data is organized)
        features = []
        labels = []
        
        for i in range(len(all_data)):
            # Separate the features
            new_feature = [all_data['D'][i], all_data['S'][i], all_data['tau'][i]]
            features.append(torch.tensor(new_feature, dtype = torch.float32))
            # Separate the labels
            #new_label = [all_data['rho'][i], all_data['eps'][i], all_data['v'][i], all_data['p'][i]]
            new_label = all_data['p'][i]
            labels.append(torch.tensor(new_label, dtype = torch.float32))
            
        # Save as instance variables to the dataloader
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        feature = self.features[idx]
        if self.transform:
            feature = transform(feature)
        label = self.labels[idx]
        if self.target_transform:
            feature = target_transform(label)
            
        return feature, label

# %% [markdown]
# Note that the following cell may be confusing. "data_train" refers to the data that was generatd above, see the pandas table. "training_data" is defined similarly as in the PyTorch tutorial, see [this page](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html) and this is an instance of the class CustomDataset defined above.

# %%
# Make training and test data, as in the tutorial
training_data = CustomDataset(data_train)
test_data = CustomDataset(data_test)

# %%
# Check if this is done correctly
print(training_data.features[:3])
print(training_data.labels[:3])
# Out:
# [tensor([0.6794, 0.1737, 0.0773]), tensor([11.3668, 13.3185,  7.7181]), tensor([4.3881, 0.3473, 7.0206])]
# [tensor(0.0372), tensor(1.1761), tensor(4.6761)]

# %%
# Now call DataLoader on the above CustomDataset instances:
train_dataloader = DataLoader(training_data, batch_size=32)
test_dataloader = DataLoader(test_data, batch_size=32)

# %% [markdown]
# # Building the neural networks

# %% [markdown]
# We will follow [this part of the PyTorch tutorial](https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html). For more information, see the [documentation page of torch.nn](https://pytorch.org/docs/stable/nn.html). We take the parameters of NNEOS

# %%
# Define hyperparameters of the model here. Will first of all put two hidden layers
# total of 800 neurons for the one in the paper
device = "cpu"
size_HL_1 = 600
size_HL_2 = 200

# Implement neural network
class NeuralNetwork(nn.Module):
    def __init__(self, size_HL_1=600, size_HL_2=200):
        super(NeuralNetwork, self).__init__()
        #self.flatten = nn.Flatten()
        self.stack = nn.Sequential(
            nn.Linear(3, size_HL_1),
            nn.Sigmoid(),
            nn.Linear(size_HL_1, size_HL_2),
            nn.Sigmoid(),
            nn.Linear(size_HL_2, 1)
        )

    def forward(self, x):
        # No flatten needed, as our input and output are 1D?
        #x = self.flatten(x) 
        logits = self.stack(x)
        return logits

# %%
# test
test_model = NeuralNetwork(100,100).to(device)
print(test_model)
# Out:
# NeuralNetwork(
#   (stack): Sequential(
#     (0): Linear(in_features=3, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=100, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Training the neural network

# %% [markdown]
# We added a regularization term, with a coefficient specified by $\lambda$ ([source](https://androidkt.com/how-to-add-l1-l2-regularization-in-pytorch-loss-function/)).

# %%
def compute_loss(pred, y, regularization=False, l1_lambda = 0.001, verbose=False):
    """Adds a regularization term on top of the used loss function.
        Note: Replace abs() with pow(2.0) for L2 regularization"""
    
    # use the specified loss function
    loss = loss_fn(pred, y)
        
    # If we use regularization:
    if regularization:
        l1_norm = sum(p.abs().sum() for p in model.parameters())
        loss += l1_lambda * l1_norm
            
    return loss

# %%
def train_loop(dataloader, model, loss_fn, optimizer, report_progress=False, regularization=False):
    """The training loop of the algorithm"""
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = compute_loss(pred, y,regularization)
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # If we want to report progress during training (not recommended - obstructs view)
        if report_progress:
            if batch % 100 == 0:
                loss, current = loss.item(), batch * len(X)
                print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn, regularization=False):
    """The testing loop of the algorithm"""
    num_batches = len(dataloader)
    test_loss = 0

    # Predict and compute losses
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += compute_loss(pred, y, regularization).item()
            
    average_test_loss = test_loss/num_batches
    return average_test_loss

# %% [markdown]
# Now we generate an instance of the above neural network in `model` (note: running this cell will create a 'fresh' model!).
#
# Save hyperparameters and loss function - note that we follow the paper. I think that their loss function agrees with [MSELoss](https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html#torch.nn.MSELoss). The paper uses the [Adam optimizer](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html#torch.optim.Adam). More details on optimizers can be found [here](https://pytorch.org/docs/stable/optim.html). Required argument `params` can be filled in by calling `model` which contains the neural network. For simplicity we will train for 10 epochs here.

# %%
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (stack): Sequential(
#     (0): Linear(in_features=3, out_features=600, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=600, out_features=200, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=200, out_features=1, bias=True)
#   )
# )

# %%
for name, param in model.state_dict().items():
    print("---")
    print(name)
    print(np.shape(param))
# Out:
# ---
# stack.0.weight
# torch.Size([600, 3])
# ---
# stack.0.bias
# torch.Size([600])
# ---
# stack.2.weight
# torch.Size([200, 600])
# ---
# stack.2.bias
# torch.Size([200])
# ---
# stack.4.weight
# torch.Size([1, 200])
# ---
# stack.4.bias
# torch.Size([1])

# %%
previous_model = torch.load("Models/NNC2Pv0t2.pth")

# %%
state_dict = previous_model.state_dict()
state_dict_items = state_dict.items()

# %%
for name, item in previous_model.state_dict().items():
    print("---")
    if name == "stack.2.weight":
        print("Saving example")
        example_matrix = item
    if name == "stack.2.bias":
        print("Saving example")
        example_vector = item
    print(name)
    print(np.shape(item))
# Out:
# ---
# stack.0.weight
# torch.Size([600, 3])
# ---
# stack.0.bias
# torch.Size([600])
# ---
# Saving example
# stack.2.weight
# torch.Size([200, 600])
# ---
# Saving example
# stack.2.bias
# torch.Size([200])
# ---
# stack.4.weight
# torch.Size([1, 200])
# ---
# stack.4.bias
# torch.Size([1])

# %%
def delete_column_tensor(x, index):
    """x is a torch tensor with shape (n, m). Returns tensor with shape (n, m-1) and deletes the column at specified index."""
    
    # Delete the column by splitting into two pieces, transpose the tensors for cat
    a = torch.transpose(x[:, :index], 0, 1)
    b = torch.transpose(x[:, index+1:], 0, 1)
    
    # Concatenate the two results, with the desired column deleted
    new = torch.cat((a, b))
    
    return torch.transpose(new, 0, 1)

# %%
def delete_row_tensor(x, index):
    """x is a torch tensor with shape (n, m). Returns tensor with shape (n, m-1) and deletes the column at specified index."""
    
    # Delete the column by splitting into two pieces, transpose the tensors for cat
    a = x[:index]
    b = x[index+1:]
    
    # Return concatenation    
    return torch.cat((a, b))

# %%
# print(example_matrix)
# print(np.shape(example_matrix))
# print("---")
# new = delete_column_tensor(example_matrix, 1)
# print(new)
# print(np.shape(new))
# print("---")
# new = delete_row_tensor(example_matrix, 1)
# print(new)
# print(np.shape(new))

# %%
# print(example_vector)
# print(np.shape(example_vector))
# print("---")
# new = delete_row_tensor(example_vector, 1)
# print(new)
# print(np.shape(new))

# %% [markdown]
# ## Pruning methods

# %%
def prune_nn_once(old_model):
    
    # Get the relevant info
    state_dict             = old_model.state_dict()
    state_dict_items = state_dict.items()
    
    # Get number of layers:
    number_of_layers = len(state_dict_items)//2
    
    # Get number of neurons in each layer (hidden + output, not input)
    number_neurons = np.array([0 for i in range(number_of_layers)])
    counter = 0
    for name, item in state_dict_items:
        if "weight" in name:
            number_neurons[counter] = np.shape(item)[0]
            counter += 1
    number_neurons_hidden = number_neurons[:-1]
    
    # Get probabilities based on this:
    probabilities_hidden_layers = number_neurons_hidden/np.sum(number_neurons_hidden)
    
    # Get the hidden layer from which we are going to prune:
    layer_index     = np.random.choice(number_of_layers-1, p=probabilities_hidden_layers)
    # Get the index of the neuron we are going to delete in this layer (uniform probability)
    neuron_index = np.random.choice(number_neurons_hidden[layer_index])
    
    # Also get layer index: they have increments of two
    layer_number = 2*layer_index + 2
    # Testing
#     print(layer_index)
#     print(neuron_index)
#     print(layer_number)
    
    # Copy the state dict of original model
    new_state_dict = state_dict.copy()
    
    # Prune that state dict:
    for key in new_state_dict:
        # Prune previous (increment -2!) weight matrix by deleting the row:
        if  str(layer_number - 2) + ".weight" in key:
            old = new_state_dict[key]
            new = delete_row_tensor(old, neuron_index)
            new_state_dict[key] = new
            
        # Prune current weight matrix by deleting the column
        if  str(layer_number) + ".weight" in key:
            old = new_state_dict[key]
            new = delete_column_tensor(old, neuron_index)
            new_state_dict[key] = new
            
        # Prune the current bias vector by deleting the row:
        if  str(layer_number-2) + ".bias" in key:
            old = new_state_dict[key]
            new = delete_row_tensor(old, neuron_index)
            new_state_dict[key] = new        
        
    # Instantiate a new model, with the appropriate number of hidden neurons, and save the pruned state dict
    new_number_neurons_hidden = number_neurons_hidden
    new_number_neurons_hidden[layer_index] -= 1
    new_model = NeuralNetwork(new_number_neurons_hidden[0], new_number_neurons_hidden[1]).to(device)
    new_model.load_state_dict(new_state_dict)
    
    return new_model

# %%
def prune_nn(old_model, number=10):
    counter = 0
    while counter < number:
        new_model = prune_nn_once(old_model)
        old_model = new_model
        counter +=1
    return new_model

# %%
new_model = prune_nn(previous_model)

# %% [markdown]
# __Training:__

# %%
print(model)

# Save hyperparameters, loss function and optimizer here (see paper for details)
learning_rate = 6e-3
batch_size = 32
adaptation_threshold = 0.9995
adaptation_multiplier = 0.5

loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# NeuralNetwork(
#   (stack): Sequential(
#     (0): Linear(in_features=3, out_features=600, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=600, out_features=200, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=200, out_features=1, bias=True)
#   )
# )

# %%
# Restart training by changing this parameter:
restart = True
abort = False
max_number_epochs = 1200

# Initialize lists in case we start a new training loop
if restart:
    confirmation = input("Are you sure you want to restart? Press y >> ")
    if confirmation == "y":
        # Empty the arrays
        test_losses = []
        train_losses = []
        train_losses_subset = []
        adaptation_indices = []
        counter = -5 # we skip the very first few iterations before changing learning rate
    else:
        print("Aborting training.")
        abort = True

# Acutal training loop is done:
if abort is False:
    epoch_counter = len(train_losses) + 1

    print("Training the model . . .")
    if restart is False:
        print("(Continued)")
        
    # Training: 
    while epoch_counter < max_number_epochs:
        print(f"\n Epoch {epoch_counter} \n --------------")
        # Train 
        train_loop(train_dataloader, model, loss_fn, optimizer)
        # Test on the training data
        average_train_loss = test_loop(train_dataloader, model, loss_fn)
        train_losses.append(average_train_loss)
        # Test on testing data
        average_test_loss = test_loop(test_dataloader, model, loss_fn)
        test_losses.append(average_test_loss)

        # Update the learning rate - see Appendix B of the paper
        # only check if update needed after 10 new epochs
        if counter >= 10:
            current = np.min(train_losses[-5:])
            previous = np.min(train_losses[-10:-5])

            # If we did not improve the test loss sufficiently, going to adapt LR
            if current/previous >= adaptation_threshold:
                # Reset counter (note: will increment later, so set to -1 st it becomes 0)
                counter = -1
                learning_rate = adaptation_multiplier*learning_rate
                print(f"Adapting learning rate to {learning_rate}")
                # Change optimizer
                optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
                # Add the epoch time for plotting later on
                adaptation_indices.append(epoch_counter)

        # Report progress:
#         print(f"Average loss of: {average_test_loss} for test data")
        print(f"Average loss of: {average_train_loss} for train data")
        
        # Another epoch passed - increment counter
        counter += 1
        epoch_counter += 1

    print("Done!")
# Out:
# Are you sure you want to restart? Press y >> y
# Training the model . . .
#
#  Epoch 1
#  --------------
# Average loss of: 0.00872820215318352 for train data
#
#  Epoch 2
#  --------------
# Average loss of: 0.007063842177391052 for train data
#
#  Epoch 3
#  --------------
# Average loss of: 0.00637879533469677 for train data
#
#  Epoch 4
#  --------------
# Average loss of: 0.00600121963750571 for train data
#
#  Epoch 5
#  --------------
# Average loss of: 0.002137273640325293 for train data
#
#  Epoch 6
#  --------------
# Average loss of: 0.001179007091803942 for train data
#
#  Epoch 7
#  --------------
# Average loss of: 0.01587883297232911 for train data
#
#  Epoch 8
#  --------------
# Average loss of: 0.0009293159693130291 for train data
#
#  Epoch 9
#  --------------
# Average loss of: 0.002137645937129855 for train data
#
#  Epoch 10
#  --------------
# Average loss of: 0.0010697434115107172 for train data
#
#  Epoch 11
#  --------------
# Average loss of: 0.0012809499812545255 for train data
#
#  Epoch 12
#  --------------
# Average loss of: 0.0010001232309150509 for train data
#
#  Epoch 13
#  --------------
# Average loss of: 0.0026040372106712313 for train data
#
#  Epoch 14
#  --------------
# Average loss of: 0.001487544204853475 for train data
#
#  Epoch 15
#  --------------
# Average loss of: 0.0022551179735921323 for train data
#
#  Epoch 16
#  --------------
# Adapting learning rate to 0.003
# Average loss of: 0.00575844113714993 for train data
#
#  Epoch 17
#  --------------
# Average loss of: 0.000609276387153659 for train data
#
#  Epoch 18
#  --------------
# Average loss of: 0.000693972263392061 for train data
#
#  Epoch 19
#  --------------
# Average loss of: 0.0004511978467286099 for train data
#
#  Epoch 20
#  --------------
# Average loss of: 0.0003898665793472901 for train data
#
#  Epoch 21
#  --------------
# Average loss of: 0.0004137193775502965 for train data
#
#  Epoch 22
#  --------------
# Average loss of: 0.0004612426474457607 for train data
#
#  Epoch 23
#  --------------
# Average loss of: 0.00030785885017830877 for train data
#
#  Epoch 24
#  --------------
# Average loss of: 0.0003292762363620568 for train data
#
#  Epoch 25
#  --------------
# Average loss of: 0.0003300172686285805 for train data
#
#  Epoch 26
#  --------------
# Average loss of: 0.00029048933630401735 for train data
#
#  Epoch 27
#  --------------
# Average loss of: 0.0005256531543331221 for train data
#
#  Epoch 28
#  --------------
# Average loss of: 0.0002909885516623035 for train data
#
#  Epoch 29
#  --------------
# Average loss of: 0.0002890575807163259 for train data
#
#  Epoch 30
#  --------------
# Average loss of: 0.0003028406996570993 for train data
#
#  Epoch 31
#  --------------
# Average loss of: 0.00023962498198961839 for train data
#
#  Epoch 32
#  --------------
# Average loss of: 0.00024335102349868975 for train data
#
#  Epoch 33
#  --------------
# Average loss of: 0.000283884256487363 for train data
#
#  Epoch 34
#  --------------
# Average loss of: 0.00040875155255780556 for train data
#
#  Epoch 35
#  --------------
# Average loss of: 0.00032179195667267775 for train data
#
#  Epoch 36
#  --------------
# Adapting learning rate to 0.0015
# Average loss of: 0.00040010120494989677 for train data
#
#  Epoch 37
#  --------------
# Average loss of: 0.00021070013459539041 for train data
#
#  Epoch 38
#  --------------
# Average loss of: 0.00020322620241495316 for train data
#
#  Epoch 39
#  --------------
# Average loss of: 0.00016132345636433456 for train data
#
#  Epoch 40
#  --------------
# Average loss of: 0.00017094722217007074 for train data
#
#  Epoch 41
#  --------------
# Average loss of: 0.00019985840612498577 for train data
#
#  Epoch 42
#  --------------
# Average loss of: 0.00020181903192424217 for train data
#
#  Epoch 43
#  --------------
# Average loss of: 0.0001554864025863935 for train data
#
#  Epoch 44
#  --------------
# Average loss of: 0.00015090446466056165 for train data
#
#  Epoch 45
#  --------------
# Average loss of: 0.00022364347504917533 for train data
#
#  Epoch 46
#  --------------
# Average loss of: 0.00014095613264362327 for train data
#
#  Epoch 47
#  --------------
# Average loss of: 0.00022452100596856325 for train data
#
#  Epoch 48
#  --------------
# Average loss of: 0.00014310723270464224 for train data
#
#  Epoch 49
#  --------------
# Average loss of: 0.0001428219454101054 for train data
#
#  Epoch 50
#  --------------
# Average loss of: 0.0001378802626786637 for train data
#
#  Epoch 51
#  --------------
# Average loss of: 0.00017852095963899047 for train data
#
#  Epoch 52
#  --------------
# Average loss of: 0.00014126794355979655 for train data
#
#  Epoch 53
#  --------------
# Average loss of: 0.0001317448405781761 for train data
#
#  Epoch 54
#  --------------
# Average loss of: 0.00013335692449472844 for train data
#
#  Epoch 55
#  --------------
# Average loss of: 0.00013043137846689205 for train data
#
#  Epoch 56
#  --------------
# Average loss of: 0.00013048078868014272 for train data
#
#  Epoch 57
#  --------------
# Average loss of: 0.0001631441487930715 for train data
#
#  Epoch 58
#  --------------
# Average loss of: 0.0001295472694648197 for train data
#
#  Epoch 59
#  --------------
# Average loss of: 0.00013169074641482438 for train data
#
#  Epoch 60
#  --------------
# Average loss of: 0.00012010777378163766 for train data
#
#  Epoch 61
#  --------------
# Average loss of: 0.0001408698357787216 for train data
#
#  Epoch 62
#  --------------
# Average loss of: 0.00017855835031659807 for train data
#
#  Epoch 63
#  --------------
# Average loss of: 0.00023203339924511966 for train data
#
#  Epoch 64
#  --------------
# Average loss of: 0.00011839749892969848 for train data
#
#  Epoch 65
#  --------------
# Average loss of: 0.00017525753688969417 for train data
#
#  Epoch 66
#  --------------
# Average loss of: 0.0003046326264855452 for train data
#
#  Epoch 67
#  --------------
# Average loss of: 0.0002574845261871815 for train data
#
#  Epoch 68
#  --------------
# Average loss of: 0.00011318558466737159 for train data
#
#  Epoch 69
#  --------------
# Average loss of: 0.00026424503661692144 for train data
#
#  Epoch 70
#  --------------
# Average loss of: 0.00011170772652694723 for train data
#
#  Epoch 71
#  --------------
# Average loss of: 0.0001610386607135297 for train data
#
#  Epoch 72
#  --------------
# Average loss of: 0.00011605568642335129 for train data
#
#  Epoch 73
#  --------------
# Average loss of: 0.00011635128995330888 for train data
#
#  Epoch 74
#  --------------
# Average loss of: 0.00011225117487629177 for train data
#
#  Epoch 75
#  --------------
# Adapting learning rate to 0.00075
# Average loss of: 0.00011647886448918143 for train data
#
#  Epoch 76
#  --------------
# Average loss of: 6.951855940533279e-05 for train data
#
#  Epoch 77
#  --------------
# Average loss of: 6.598850594709803e-05 for train data
#
#  Epoch 78
#  --------------
# Average loss of: 6.541063471704547e-05 for train data
#
#  Epoch 79
#  --------------
# Average loss of: 6.507027177030977e-05 for train data
#
#  Epoch 80
#  --------------
# Average loss of: 6.436837401233788e-05 for train data
#
#  Epoch 81
#  --------------
# Average loss of: 7.120331800942949e-05 for train data
#
#  Epoch 82
#  --------------
# Average loss of: 7.66417437196651e-05 for train data
#
#  Epoch 83
#  --------------
# Average loss of: 6.853965578702627e-05 for train data
#
#  Epoch 84
#  --------------
# Average loss of: 7.457722644139721e-05 for train data
#
#  Epoch 85
#  --------------
# Average loss of: 7.61015775926353e-05 for train data
#
#  Epoch 86
#  --------------
# Adapting learning rate to 0.000375
# Average loss of: 7.471463348629186e-05 for train data
#
#  Epoch 87
#  --------------
# Average loss of: 4.9740111243590946e-05 for train data
#
#  Epoch 88
#  --------------
# Average loss of: 4.949351937138999e-05 for train data
#
#  Epoch 89
#  --------------
# Average loss of: 4.922794692211028e-05 for train data
#
#  Epoch 90
#  --------------
# Average loss of: 4.898795870922186e-05 for train data
#
#  Epoch 91
#  --------------
# Average loss of: 4.8749670710822104e-05 for train data
#
#  Epoch 92
#  --------------
# Average loss of: 4.8552010485764186e-05 for train data
#
#  Epoch 93
#  --------------
# Average loss of: 4.82848930723776e-05 for train data
#
#  Epoch 94
#  --------------
# Average loss of: 4.7788670507543426e-05 for train data
#
#  Epoch 95
#  --------------
# Average loss of: 4.767968487285543e-05 for train data
#
#  Epoch 96
#  --------------
# Average loss of: 4.770044633605721e-05 for train data
#
#  Epoch 97
#  --------------
# Average loss of: 4.7476288355392174e-05 for train data
#
#  Epoch 98
#  --------------
# Average loss of: 4.726605654832383e-05 for train data
#
#  Epoch 99
#  --------------
# Average loss of: 4.6690779056189055e-05 for train data
#
#  Epoch 100
#  --------------
# Average loss of: 4.6521267741627525e-05 for train data
#
#  Epoch 101
#  --------------
# Average loss of: 4.6325746760885524e-05 for train data
#
#  Epoch 102
#  --------------
# Average loss of: 4.628524026829837e-05 for train data
#
#  Epoch 103
#  --------------
# Average loss of: 4.6133683936750455e-05 for train data
#
#  Epoch 104
#  --------------
# Average loss of: 4.5974988965645024e-05 for train data
#
#  Epoch 105
#  --------------
# Average loss of: 4.579538890375261e-05 for train data
#
#  Epoch 106
#  --------------
# Average loss of: 4.561426963919075e-05 for train data
#
#  Epoch 107
#  --------------
# Average loss of: 4.544417599445296e-05 for train data
#
#  Epoch 108
#  --------------
# Average loss of: 4.528103824122809e-05 for train data
#
#  Epoch 109
#  --------------
# Average loss of: 4.512432956089469e-05 for train data
#
#  Epoch 110
#  --------------
# Average loss of: 4.498039068912476e-05 for train data
#
#  Epoch 111
#  --------------
# Average loss of: 4.4843177819711854e-05 for train data
#
#  Epoch 112
#  --------------
# Average loss of: 4.471391440856678e-05 for train data
#
#  Epoch 113
#  --------------
# Average loss of: 4.459104540510452e-05 for train data
#
#  Epoch 114
#  --------------
# Average loss of: 4.447673409122217e-05 for train data
#
#  Epoch 115
#  --------------
# Average loss of: 4.43667259913127e-05 for train data
#
#  Epoch 116
#  --------------
# Average loss of: 4.426423804507067e-05 for train data
#
#  Epoch 117
#  --------------
# Average loss of: 4.4166907367252864e-05 for train data
#
#  Epoch 118
#  --------------
# Average loss of: 4.407303191110259e-05 for train data
#
#  Epoch 119
#  --------------
# Average loss of: 4.398299535550905e-05 for train data
#
#  Epoch 120
#  --------------
# Average loss of: 4.389702331100125e-05 for train data
#
#  Epoch 121
#  --------------
# Average loss of: 4.3817252352710056e-05 for train data
#
#  Epoch 122
#  --------------
# Average loss of: 4.373816305760556e-05 for train data
#
#  Epoch 123
#  --------------
# Average loss of: 4.3661786059419684e-05 for train data
#
#  Epoch 124
#  --------------
# Average loss of: 4.358779824033263e-05 for train data
#
#  Epoch 125
#  --------------
# Average loss of: 4.3515469064914215e-05 for train data
#
#  Epoch 126
#  --------------
# Average loss of: 4.344604688903928e-05 for train data
#
#  Epoch 127
#  --------------
# Average loss of: 4.337567520015e-05 for train data
#
#  Epoch 128
#  --------------
# Average loss of: 4.3307555081992175e-05 for train data
#
#  Epoch 129
#  --------------
# Average loss of: 4.323906593162974e-05 for train data
#
#  Epoch 130
#  --------------
# Average loss of: 4.316763738061127e-05 for train data
#
#  Epoch 131
#  --------------
# Average loss of: 4.3096947436060875e-05 for train data
#
#  Epoch 132
#  --------------
# Average loss of: 4.302310236798803e-05 for train data
#
#  Epoch 133
#  --------------
# Average loss of: 4.2945580632476774e-05 for train data
#
#  Epoch 134
#  --------------
# Average loss of: 4.287069073070597e-05 for train data
#
#  Epoch 135
#  --------------
# Average loss of: 4.279394115801552e-05 for train data
#
#  Epoch 136
#  --------------
# Average loss of: 4.271474393790413e-05 for train data
#
#  Epoch 137
#  --------------
# Average loss of: 4.2642423640063496e-05 for train data
#
#  Epoch 138
#  --------------
# Average loss of: 4.257812960495357e-05 for train data
#
#  Epoch 139
#  --------------
# Average loss of: 4.252638459947775e-05 for train data
#
#  Epoch 140
#  --------------
# Average loss of: 4.248510642973997e-05 for train data
#
#  Epoch 141
#  --------------
# Average loss of: 4.244777408821392e-05 for train data
#
#  Epoch 142
#  --------------
# Average loss of: 4.2389122985150604e-05 for train data
#
#  Epoch 143
#  --------------
# Average loss of: 4.230375117804215e-05 for train data
#
#  Epoch 144
#  --------------
# Average loss of: 4.2168422833856314e-05 for train data
#
#  Epoch 145
#  --------------
# Average loss of: 4.201116991316667e-05 for train data
#
#  Epoch 146
#  --------------
# Average loss of: 4.1898821221184335e-05 for train data
#
#  Epoch 147
#  --------------
# Average loss of: 4.1810102726049084e-05 for train data
#
#  Epoch 148
#  --------------
# Average loss of: 4.1723567875669686e-05 for train data
#
#  Epoch 149
#  --------------
# Average loss of: 4.1635882830996706e-05 for train data
#
#  Epoch 150
#  --------------
# Average loss of: 4.154323844395549e-05 for train data
#
#  Epoch 151
#  --------------
# Average loss of: 4.1448648966252224e-05 for train data
#
#  Epoch 152
#  --------------
# Average loss of: 4.135640172207786e-05 for train data
#
#  Epoch 153
#  --------------
# Average loss of: 4.126951353155164e-05 for train data
#
#  Epoch 154
#  --------------
# Average loss of: 4.118853698091698e-05 for train data
#
#  Epoch 155
#  --------------
# Average loss of: 4.111277878546389e-05 for train data
#
#  Epoch 156
#  --------------
# Average loss of: 4.103783468672191e-05 for train data
#
#  Epoch 157
#  --------------
# Average loss of: 4.096650313076679e-05 for train data
#
#  Epoch 158
#  --------------
# Average loss of: 4.08982529761488e-05 for train data
#
#  Epoch 159
#  --------------
# Average loss of: 4.084349159602425e-05 for train data
#
#  Epoch 160
#  --------------
# Average loss of: 4.079987061486463e-05 for train data
#
#  Epoch 161
#  --------------
# Average loss of: 4.076223202409892e-05 for train data
#
#  Epoch 162
#  --------------
# Average loss of: 4.0715848091895166e-05 for train data
#
#  Epoch 163
#  --------------
# Average loss of: 4.06660007291066e-05 for train data
#
#  Epoch 164
#  --------------
# Average loss of: 4.060916993439605e-05 for train data
#
#  Epoch 165
#  --------------
# Average loss of: 4.054531084439077e-05 for train data
#
#  Epoch 166
#  --------------
# Average loss of: 4.047709591868625e-05 for train data
#
#  Epoch 167
#  --------------
# Average loss of: 4.040305736834853e-05 for train data
#
#  Epoch 168
#  --------------
# Average loss of: 4.032725480610679e-05 for train data
#
#  Epoch 169
#  --------------
# Average loss of: 4.0248863846318274e-05 for train data
#
#  Epoch 170
#  --------------
# Average loss of: 4.0168185866969e-05 for train data
#
#  Epoch 171
#  --------------
# Average loss of: 4.00900672417265e-05 for train data
#
#  Epoch 172
#  --------------
# Average loss of: 4.0008995341486295e-05 for train data
#
#  Epoch 173
#  --------------
# Average loss of: 3.993065990598552e-05 for train data
#
#  Epoch 174
#  --------------
# Average loss of: 3.985186043628346e-05 for train data
#
#  Epoch 175
#  --------------
# Average loss of: 3.977335531308199e-05 for train data
#
#  Epoch 176
#  --------------
# Average loss of: 3.969661772516702e-05 for train data
#
#  Epoch 177
#  --------------
# Average loss of: 3.961947500320093e-05 for train data
#
#  Epoch 178
#  --------------
# Average loss of: 3.9544458046475484e-05 for train data
#
#  Epoch 179
#  --------------
# Average loss of: 3.947066295677359e-05 for train data
#
#  Epoch 180
#  --------------
# Average loss of: 3.9397169820404086e-05 for train data
#
#  Epoch 181
#  --------------
# Average loss of: 3.93245055245643e-05 for train data
#
#  Epoch 182
#  --------------
# Average loss of: 3.9250699172407625e-05 for train data
#
#  Epoch 183
#  --------------
# Average loss of: 3.917529996488156e-05 for train data
#
#  Epoch 184
#  --------------
# Average loss of: 3.9098500867658e-05 for train data
#
#  Epoch 185
#  --------------
# Average loss of: 3.9017253618294486e-05 for train data
#
#  Epoch 186
#  --------------
# Average loss of: 3.893474065880582e-05 for train data
#
#  Epoch 187
#  --------------
# Average loss of: 3.885043031823443e-05 for train data
#
#  Epoch 188
#  --------------
# Average loss of: 3.877020389954851e-05 for train data
#
#  Epoch 189
#  --------------
# Average loss of: 3.8699885861569785e-05 for train data
#
#  Epoch 190
#  --------------
# Average loss of: 3.8638418202572214e-05 for train data
#
#  Epoch 191
#  --------------
# Average loss of: 3.858549040305661e-05 for train data
#
#  Epoch 192
#  --------------
# Average loss of: 3.8531627726843e-05 for train data
#
#  Epoch 193
#  --------------
# Average loss of: 3.848393690059311e-05 for train data
#
#  Epoch 194
#  --------------
# Average loss of: 3.8437061065087616e-05 for train data
#
#  Epoch 195
#  --------------
# Average loss of: 3.839994664940605e-05 for train data
#
#  Epoch 196
#  --------------
# Average loss of: 3.834147079724062e-05 for train data
#
#  Epoch 197
#  --------------
# Average loss of: 3.8301719641276574e-05 for train data
#
#  Epoch 198
#  --------------
# Average loss of: 3.821907075925992e-05 for train data
#
#  Epoch 199
#  --------------
# Average loss of: 3.820299303697539e-05 for train data
#
#  Epoch 200
#  --------------
# Average loss of: 3.8055111950961875e-05 for train data
#
#  Epoch 201
#  --------------
# Average loss of: 3.808664730422606e-05 for train data
#
#  Epoch 202
#  --------------
# Average loss of: 3.797454018276767e-05 for train data
#
#  Epoch 203
#  --------------
# Average loss of: 3.796052513134782e-05 for train data
#
#  Epoch 204
#  --------------
# Average loss of: 3.788569895114051e-05 for train data
#
#  Epoch 205
#  --------------
# Average loss of: 3.782982475058816e-05 for train data
#
#  Epoch 206
#  --------------
# Average loss of: 3.77691244109883e-05 for train data
#
#  Epoch 207
#  --------------
# Average loss of: 3.7708422615651213e-05 for train data
#
#  Epoch 208
#  --------------
# Average loss of: 3.7647519157508216e-05 for train data
#
#  Epoch 209
#  --------------
# Average loss of: 3.7587011734285626e-05 for train data
#
#  Epoch 210
#  --------------
# Average loss of: 3.7526607632025844e-05 for train data
#
#  Epoch 211
#  --------------
# Average loss of: 3.7465821503246845e-05 for train data
#
#  Epoch 212
#  --------------
# Average loss of: 3.740292342627072e-05 for train data
#
#  Epoch 213
#  --------------
# Average loss of: 3.733729711548221e-05 for train data
#
#  Epoch 214
#  --------------
# Average loss of: 3.726029297504283e-05 for train data
#
#  Epoch 215
#  --------------
# Average loss of: 3.716839598710067e-05 for train data
#
#  Epoch 216
#  --------------
# Average loss of: 3.712815688668343e-05 for train data
#
#  Epoch 217
#  --------------
# Average loss of: 3.7058527227418383e-05 for train data
#
#  Epoch 218
#  --------------
# Average loss of: 3.7013717686022576e-05 for train data
#
#  Epoch 219
#  --------------
# Average loss of: 3.6946073323815656e-05 for train data
#
#  Epoch 220
#  --------------
# Average loss of: 3.6902909252057727e-05 for train data
#
#  Epoch 221
#  --------------
# Average loss of: 3.683226156535966e-05 for train data
#
#  Epoch 222
#  --------------
# Average loss of: 3.678977185954864e-05 for train data
#
#  Epoch 223
#  --------------
# Average loss of: 3.671957787755673e-05 for train data
#
#  Epoch 224
#  --------------
# Average loss of: 3.6675016721346764e-05 for train data
#
#  Epoch 225
#  --------------
# Average loss of: 3.660967066261946e-05 for train data
#
#  Epoch 226
#  --------------
# Average loss of: 3.655850698123686e-05 for train data
#
#  Epoch 227
#  --------------
# Average loss of: 3.64991907545118e-05 for train data
#
#  Epoch 228
#  --------------
# Average loss of: 3.6442216544310215e-05 for train data
#
#  Epoch 229
#  --------------
# Average loss of: 3.638457951910823e-05 for train data
#
#  Epoch 230
#  --------------
# Average loss of: 3.632603242149344e-05 for train data
#
#  Epoch 231
#  --------------
# Average loss of: 3.6267885445340655e-05 for train data
#
#  Epoch 232
#  --------------
# Average loss of: 3.62097269797232e-05 for train data
#
#  Epoch 233
#  --------------
# Average loss of: 3.6151053124740426e-05 for train data
#
#  Epoch 234
#  --------------
# Average loss of: 3.609284385456703e-05 for train data
#
#  Epoch 235
#  --------------
# Average loss of: 3.6035568579973186e-05 for train data
#
#  Epoch 236
#  --------------
# Average loss of: 3.597757563293271e-05 for train data
#
#  Epoch 237
#  --------------
# Average loss of: 3.591964463739714e-05 for train data
#
#  Epoch 238
#  --------------
# Average loss of: 3.5861587287581645e-05 for train data
#
#  Epoch 239
#  --------------
# Average loss of: 3.580435485091584e-05 for train data
#
#  Epoch 240
#  --------------
# Average loss of: 3.574613253622374e-05 for train data
#
#  Epoch 241
#  --------------
# Average loss of: 3.568861717321852e-05 for train data
#
#  Epoch 242
#  --------------
# Average loss of: 3.563225171155864e-05 for train data
#
#  Epoch 243
#  --------------
# Average loss of: 3.5575208098634906e-05 for train data
#
#  Epoch 244
#  --------------
# Average loss of: 3.5518043973297606e-05 for train data
#
#  Epoch 245
#  --------------
# Average loss of: 3.546196630613849e-05 for train data
#
#  Epoch 246
#  --------------
# Average loss of: 3.540535698102758e-05 for train data
#
#  Epoch 247
#  --------------
# Average loss of: 3.53484757410115e-05 for train data
#
#  Epoch 248
#  --------------
# Average loss of: 3.5292319904419856e-05 for train data
#
#  Epoch 249
#  --------------
# Average loss of: 3.523675697879298e-05 for train data
#
#  Epoch 250
#  --------------
# Average loss of: 3.518103116784914e-05 for train data
#
#  Epoch 251
#  --------------
# Average loss of: 3.512660676760788e-05 for train data
#
#  Epoch 252
#  --------------
# Average loss of: 3.507170966067861e-05 for train data
#
#  Epoch 253
#  --------------
# Average loss of: 3.5018925714575744e-05 for train data
#
#  Epoch 254
#  --------------
# Average loss of: 3.496602885707034e-05 for train data
#
#  Epoch 255
#  --------------
# Average loss of: 3.4914165944610434e-05 for train data
#
#  Epoch 256
#  --------------
# Average loss of: 3.4858858205643626e-05 for train data
#
#  Epoch 257
#  --------------
# Average loss of: 3.480520885386795e-05 for train data
#
#  Epoch 258
#  --------------
# Average loss of: 3.474322479842158e-05 for train data
#
#  Epoch 259
#  --------------
# Average loss of: 3.469098223240508e-05 for train data
#
#  Epoch 260
#  --------------
# Average loss of: 3.4617099922979834e-05 for train data
#
#  Epoch 261
#  --------------
# Average loss of: 3.455747251537104e-05 for train data
#
#  Epoch 262
#  --------------
# Average loss of: 3.448520420879504e-05 for train data
#
#  Epoch 263
#  --------------
# Average loss of: 3.441888420866235e-05 for train data
#
#  Epoch 264
#  --------------
# Average loss of: 3.437143367445969e-05 for train data
#
#  Epoch 265
#  --------------
# Average loss of: 3.447723001354461e-05 for train data
#
#  Epoch 266
#  --------------
# Average loss of: 3.528008142911858e-05 for train data
#
#  Epoch 267
#  --------------
# Average loss of: 3.424594593116126e-05 for train data
#
#  Epoch 268
#  --------------
# Average loss of: 3.456409806622105e-05 for train data
#
#  Epoch 269
#  --------------
# Average loss of: 3.455120878688831e-05 for train data
#
#  Epoch 270
#  --------------
# Average loss of: 3.469837399206881e-05 for train data
#
#  Epoch 271
#  --------------
# Average loss of: 3.436590700466695e-05 for train data
#
#  Epoch 272
#  --------------
# Adapting learning rate to 0.0001875
# Average loss of: 3.4669144417421194e-05 for train data
#
#  Epoch 273
#  --------------
# Average loss of: 2.520976799755772e-05 for train data
#
#  Epoch 274
#  --------------
# Average loss of: 2.505699251887563e-05 for train data
#
#  Epoch 275
#  --------------
# Average loss of: 2.4976992110623543e-05 for train data
#
#  Epoch 276
#  --------------
# Average loss of: 2.4915448179854138e-05 for train data
#
#  Epoch 277
#  --------------
# Average loss of: 2.4860085713771695e-05 for train data
#
#  Epoch 278
#  --------------
# Average loss of: 2.480732892749984e-05 for train data
#
#  Epoch 279
#  --------------
# Average loss of: 2.4756706079460855e-05 for train data
#
#  Epoch 280
#  --------------
# Average loss of: 2.4708794866910466e-05 for train data
#
#  Epoch 281
#  --------------
# Average loss of: 2.466260239125404e-05 for train data
#
#  Epoch 282
#  --------------
# Average loss of: 2.4617481228688122e-05 for train data
#
#  Epoch 283
#  --------------
# Average loss of: 2.4574030852045327e-05 for train data
#
#  Epoch 284
#  --------------
# Average loss of: 2.4532178269646466e-05 for train data
#
#  Epoch 285
#  --------------
# Average loss of: 2.4490178431051392e-05 for train data
#
#  Epoch 286
#  --------------
# Average loss of: 2.4449800009915633e-05 for train data
#
#  Epoch 287
#  --------------
# Average loss of: 2.4408970198555833e-05 for train data
#
#  Epoch 288
#  --------------
# Average loss of: 2.437035063494477e-05 for train data
#
#  Epoch 289
#  --------------
# Average loss of: 2.4330528556401988e-05 for train data
#
#  Epoch 290
#  --------------
# Average loss of: 2.429227123311648e-05 for train data
#
#  Epoch 291
#  --------------
# Average loss of: 2.425196275357848e-05 for train data
#
#  Epoch 292
#  --------------
# Average loss of: 2.421225625457737e-05 for train data
#
#  Epoch 293
#  --------------
# Average loss of: 2.417088541906196e-05 for train data
#
#  Epoch 294
#  --------------
# Average loss of: 2.4127708434980378e-05 for train data
#
#  Epoch 295
#  --------------
# Average loss of: 2.408218313657926e-05 for train data
#
#  Epoch 296
#  --------------
# Average loss of: 2.403518391279249e-05 for train data
#
#  Epoch 297
#  --------------
# Average loss of: 2.398535204924883e-05 for train data
#
#  Epoch 298
#  --------------
# Average loss of: 2.393869577699661e-05 for train data
#
#  Epoch 299
#  --------------
# Average loss of: 2.3887062521225742e-05 for train data
#
#  Epoch 300
#  --------------
# Average loss of: 2.3840319645523777e-05 for train data
#
#  Epoch 301
#  --------------
# Average loss of: 2.3793173907415623e-05 for train data
#
#  Epoch 302
#  --------------
# Average loss of: 2.3750755834680605e-05 for train data
#
#  Epoch 303
#  --------------
# Average loss of: 2.3710838874922046e-05 for train data
#
#  Epoch 304
#  --------------
# Average loss of: 2.3663316328747898e-05 for train data
#
#  Epoch 305
#  --------------
# Average loss of: 2.3622931768522902e-05 for train data
#
#  Epoch 306
#  --------------
# Average loss of: 2.3558367411533256e-05 for train data
#
#  Epoch 307
#  --------------
# Average loss of: 2.3534730350775136e-05 for train data
#
#  Epoch 308
#  --------------
# Average loss of: 2.3512064509714036e-05 for train data
#
#  Epoch 309
#  --------------
# Average loss of: 2.3476304413907202e-05 for train data
#
#  Epoch 310
#  --------------
# Average loss of: 2.345111429140161e-05 for train data
#
#  Epoch 311
#  --------------
# Average loss of: 2.338515716605798e-05 for train data
#
#  Epoch 312
#  --------------
# Average loss of: 2.338166658450973e-05 for train data
#
#  Epoch 313
#  --------------
# Average loss of: 2.331234142925496e-05 for train data
#
#  Epoch 314
#  --------------
# Average loss of: 2.3703167536086766e-05 for train data
#
#  Epoch 315
#  --------------
# Average loss of: 2.3211239184547594e-05 for train data
#
#  Epoch 316
#  --------------
# Average loss of: 2.3642257096116736e-05 for train data
#
#  Epoch 317
#  --------------
# Average loss of: 2.3138522477302103e-05 for train data
#
#  Epoch 318
#  --------------
# Average loss of: 2.3547021840386152e-05 for train data
#
#  Epoch 319
#  --------------
# Average loss of: 2.3065321798549122e-05 for train data
#
#  Epoch 320
#  --------------
# Average loss of: 2.307167726703483e-05 for train data
#
#  Epoch 321
#  --------------
# Average loss of: 2.29982063130592e-05 for train data
#
#  Epoch 322
#  --------------
# Average loss of: 2.289916890099448e-05 for train data
#
#  Epoch 323
#  --------------
# Average loss of: 2.2929333201409464e-05 for train data
#
#  Epoch 324
#  --------------
# Average loss of: 2.2858313851020284e-05 for train data
#
#  Epoch 325
#  --------------
# Average loss of: 2.2802234982373193e-05 for train data
#
#  Epoch 326
#  --------------
# Average loss of: 2.282648211930791e-05 for train data
#
#  Epoch 327
#  --------------
# Average loss of: 2.276390060974336e-05 for train data
#
#  Epoch 328
#  --------------
# Average loss of: 2.2706887004869713e-05 for train data
#
#  Epoch 329
#  --------------
# Average loss of: 2.2728804485495856e-05 for train data
#
#  Epoch 330
#  --------------
# Average loss of: 2.2690612085671093e-05 for train data
#
#  Epoch 331
#  --------------
# Average loss of: 2.2542541282609817e-05 for train data
#
#  Epoch 332
#  --------------
# Average loss of: 2.2624536791363426e-05 for train data
#
#  Epoch 333
#  --------------
# Average loss of: 2.2597808432965395e-05 for train data
#
#  Epoch 334
#  --------------
# Average loss of: 2.2568360785999175e-05 for train data
#
#  Epoch 335
#  --------------
# Average loss of: 2.2540677438928468e-05 for train data
#
#  Epoch 336
#  --------------
# Average loss of: 2.2509455942508792e-05 for train data
#
#  Epoch 337
#  --------------
# Average loss of: 2.247427301958851e-05 for train data
#
#  Epoch 338
#  --------------
# Average loss of: 2.244080273376312e-05 for train data
#
#  Epoch 339
#  --------------
# Average loss of: 2.2408590886243475e-05 for train data
#
#  Epoch 340
#  --------------
# Average loss of: 2.237035165076122e-05 for train data
#
#  Epoch 341
#  --------------
# Average loss of: 2.234278781575085e-05 for train data
#
#  Epoch 342
#  --------------
# Average loss of: 2.232057400597114e-05 for train data
#
#  Epoch 343
#  --------------
# Average loss of: 2.2211818483947354e-05 for train data
#
#  Epoch 344
#  --------------
# Average loss of: 2.2217717110788727e-05 for train data
#
#  Epoch 345
#  --------------
# Average loss of: 2.2206725495789215e-05 for train data
#
#  Epoch 346
#  --------------
# Average loss of: 2.2178506740738157e-05 for train data
#
#  Epoch 347
#  --------------
# Average loss of: 2.2192872054620238e-05 for train data
#
#  Epoch 348
#  --------------
# Average loss of: 2.203966070783281e-05 for train data
#
#  Epoch 349
#  --------------
# Average loss of: 2.2017277956501856e-05 for train data
#
#  Epoch 350
#  --------------
# Average loss of: 2.1979569237009855e-05 for train data
#
#  Epoch 351
#  --------------
# Average loss of: 2.195443346136017e-05 for train data
#
#  Epoch 352
#  --------------
# Average loss of: 2.1925098196243198e-05 for train data
#
#  Epoch 353
#  --------------
# Average loss of: 2.189958267426846e-05 for train data
#
#  Epoch 354
#  --------------
# Average loss of: 2.1870655844213616e-05 for train data
#
#  Epoch 355
#  --------------
# Average loss of: 2.1841191862540656e-05 for train data
#
#  Epoch 356
#  --------------
# Average loss of: 2.1808079342008568e-05 for train data
#
#  Epoch 357
#  --------------
# Average loss of: 2.1783812427293013e-05 for train data
#
#  Epoch 358
#  --------------
# Average loss of: 2.1756732693120283e-05 for train data
#
#  Epoch 359
#  --------------
# Average loss of: 2.1731278924971775e-05 for train data
#
#  Epoch 360
#  --------------
# Average loss of: 2.1708148741936383e-05 for train data
#
#  Epoch 361
#  --------------
# Average loss of: 2.168055160559561e-05 for train data
#
#  Epoch 362
#  --------------
# Average loss of: 2.1656994414570362e-05 for train data
#
#  Epoch 363
#  --------------
# Average loss of: 2.1630630631034363e-05 for train data
#
#  Epoch 364
#  --------------
# Average loss of: 2.1604537704843096e-05 for train data
#
#  Epoch 365
#  --------------
# Average loss of: 2.1578602989893625e-05 for train data
#
#  Epoch 366
#  --------------
# Average loss of: 2.1552688096380733e-05 for train data
#
#  Epoch 367
#  --------------
# Average loss of: 2.1526280855641742e-05 for train data
#
#  Epoch 368
#  --------------
# Average loss of: 2.150210876438905e-05 for train data
#
#  Epoch 369
#  --------------
# Average loss of: 2.1475574199257606e-05 for train data
#
#  Epoch 370
#  --------------
# Average loss of: 2.145045609686349e-05 for train data
#
#  Epoch 371
#  --------------
# Average loss of: 2.1425661502735237e-05 for train data
#
#  Epoch 372
#  --------------
# Average loss of: 2.1400742941432328e-05 for train data
#
#  Epoch 373
#  --------------
# Average loss of: 2.137607781414772e-05 for train data
#
#  Epoch 374
#  --------------
# Average loss of: 2.1351687964624944e-05 for train data
#
#  Epoch 375
#  --------------
# Average loss of: 2.1327548624003612e-05 for train data
#
#  Epoch 376
#  --------------
# Average loss of: 2.1303150188350626e-05 for train data
#
#  Epoch 377
#  --------------
# Average loss of: 2.127905589331931e-05 for train data
#
#  Epoch 378
#  --------------
# Average loss of: 2.1255045804809926e-05 for train data
#
#  Epoch 379
#  --------------
# Average loss of: 2.1231394939286475e-05 for train data
#
#  Epoch 380
#  --------------
# Average loss of: 2.1207198757883818e-05 for train data
#
#  Epoch 381
#  --------------
# Average loss of: 2.1182529118232195e-05 for train data
#
#  Epoch 382
#  --------------
# Average loss of: 2.1157275546738673e-05 for train data
#
#  Epoch 383
#  --------------
# Average loss of: 2.1131938529879337e-05 for train data
#
#  Epoch 384
#  --------------
# Average loss of: 2.1106579414436055e-05 for train data
#
#  Epoch 385
#  --------------
# Average loss of: 2.1081785980277346e-05 for train data
#
#  Epoch 386
#  --------------
# Average loss of: 2.105682572046135e-05 for train data
#
#  Epoch 387
#  --------------
# Average loss of: 2.1032095529244543e-05 for train data
#
#  Epoch 388
#  --------------
# Average loss of: 2.10072545341518e-05 for train data
#
#  Epoch 389
#  --------------
# Average loss of: 2.0982562485414745e-05 for train data
#
#  Epoch 390
#  --------------
# Average loss of: 2.0957488392559755e-05 for train data
#
#  Epoch 391
#  --------------
# Average loss of: 2.0932848461552568e-05 for train data
#
#  Epoch 392
#  --------------
# Average loss of: 2.090787398615248e-05 for train data
#
#  Epoch 393
#  --------------
# Average loss of: 2.088258677099475e-05 for train data
#
#  Epoch 394
#  --------------
# Average loss of: 2.085752125472027e-05 for train data
#
#  Epoch 395
#  --------------
# Average loss of: 2.08326202425269e-05 for train data
#
#  Epoch 396
#  --------------
# Average loss of: 2.0807341872705366e-05 for train data
#
#  Epoch 397
#  --------------
# Average loss of: 2.0782681981563655e-05 for train data
#
#  Epoch 398
#  --------------
# Average loss of: 2.0757478513587557e-05 for train data
#
#  Epoch 399
#  --------------
# Average loss of: 2.0732007422884634e-05 for train data
#
#  Epoch 400
#  --------------
# Average loss of: 2.0707543704611454e-05 for train data
#
#  Epoch 401
#  --------------
# Average loss of: 2.0682218356250815e-05 for train data
#
#  Epoch 402
#  --------------
# Average loss of: 2.0657560455038036e-05 for train data
#
#  Epoch 403
#  --------------
# Average loss of: 2.0633117477746054e-05 for train data
#
#  Epoch 404
#  --------------
# Average loss of: 2.060889978306477e-05 for train data
#
#  Epoch 405
#  --------------
# Average loss of: 2.0584495460980177e-05 for train data
#
#  Epoch 406
#  --------------
# Average loss of: 2.0560605213586315e-05 for train data
#
#  Epoch 407
#  --------------
# Average loss of: 2.053672869728871e-05 for train data
#
#  Epoch 408
#  --------------
# Average loss of: 2.051316587030669e-05 for train data
#
#  Epoch 409
#  --------------
# Average loss of: 2.0489797757500128e-05 for train data
#
#  Epoch 410
#  --------------
# Average loss of: 2.046662521838698e-05 for train data
#
#  Epoch 411
#  --------------
# Average loss of: 2.0443896122151273e-05 for train data
#
#  Epoch 412
#  --------------
# Average loss of: 2.0420993454627022e-05 for train data
#
#  Epoch 413
#  --------------
# Average loss of: 2.0398857511463574e-05 for train data
#
#  Epoch 414
#  --------------
# Average loss of: 2.0376202765328344e-05 for train data
#
#  Epoch 415
#  --------------
# Average loss of: 2.035391777390032e-05 for train data
#
#  Epoch 416
#  --------------
# Average loss of: 2.0331446309273815e-05 for train data
#
#  Epoch 417
#  --------------
# Average loss of: 2.0309918866769295e-05 for train data
#
#  Epoch 418
#  --------------
# Average loss of: 2.0286412495170225e-05 for train data
#
#  Epoch 419
#  --------------
# Average loss of: 2.0265671115248552e-05 for train data
#
#  Epoch 420
#  --------------
# Average loss of: 2.024346786811293e-05 for train data
#
#  Epoch 421
#  --------------
# Average loss of: 2.022087424525125e-05 for train data
#
#  Epoch 422
#  --------------
# Average loss of: 2.0199600674595785e-05 for train data
#
#  Epoch 423
#  --------------
# Average loss of: 2.0177966739447585e-05 for train data
#
#  Epoch 424
#  --------------
# Average loss of: 2.0157128043138074e-05 for train data
#
#  Epoch 425
#  --------------
# Average loss of: 2.0136487200215926e-05 for train data
#
#  Epoch 426
#  --------------
# Average loss of: 2.0111640259256092e-05 for train data
#
#  Epoch 427
#  --------------
# Average loss of: 2.0089731335838223e-05 for train data
#
#  Epoch 428
#  --------------
# Average loss of: 2.0069455695920625e-05 for train data
#
#  Epoch 429
#  --------------
# Average loss of: 2.0049064154545704e-05 for train data
#
#  Epoch 430
#  --------------
# Average loss of: 2.0026544372831268e-05 for train data
#
#  Epoch 431
#  --------------
# Average loss of: 2.000455017737295e-05 for train data
#
#  Epoch 432
#  --------------
# Average loss of: 1.9982631851280532e-05 for train data
#
#  Epoch 433
#  --------------
# Average loss of: 1.996147814975302e-05 for train data
#
#  Epoch 434
#  --------------
# Average loss of: 1.9940114617838843e-05 for train data
#
#  Epoch 435
#  --------------
# Average loss of: 1.9919144960113046e-05 for train data
#
#  Epoch 436
#  --------------
# Average loss of: 1.9898010023507596e-05 for train data
#
#  Epoch 437
#  --------------
# Average loss of: 1.9877597393679026e-05 for train data
#
#  Epoch 438
#  --------------
# Average loss of: 1.9856918566165406e-05 for train data
#
#  Epoch 439
#  --------------
# Average loss of: 1.983651151876984e-05 for train data
#
#  Epoch 440
#  --------------
# Average loss of: 1.9815890041627428e-05 for train data
#
#  Epoch 441
#  --------------
# Average loss of: 1.9795789420550135e-05 for train data
#
#  Epoch 442
#  --------------
# Average loss of: 1.9775603347670767e-05 for train data
#
#  Epoch 443
#  --------------
# Average loss of: 1.9755270905170617e-05 for train data
#
#  Epoch 444
#  --------------
# Average loss of: 1.9735010449949188e-05 for train data
#
#  Epoch 445
#  --------------
# Average loss of: 1.971559579719724e-05 for train data
#
#  Epoch 446
#  --------------
# Average loss of: 1.9695320321852705e-05 for train data
#
#  Epoch 447
#  --------------
# Average loss of: 1.967619292931886e-05 for train data
#
#  Epoch 448
#  --------------
# Average loss of: 1.9656447627539818e-05 for train data
#
#  Epoch 449
#  --------------
# Average loss of: 1.9636980430914263e-05 for train data
#
#  Epoch 450
#  --------------
# Average loss of: 1.961726198569522e-05 for train data
#
#  Epoch 451
#  --------------
# Average loss of: 1.9598119760030385e-05 for train data
#
#  Epoch 452
#  --------------
# Average loss of: 1.9578417723323584e-05 for train data
#
#  Epoch 453
#  --------------
# Average loss of: 1.9558921660336637e-05 for train data
#
#  Epoch 454
#  --------------
# Average loss of: 1.953971333305162e-05 for train data
#
#  Epoch 455
#  --------------
# Average loss of: 1.9520168380086034e-05 for train data
#
#  Epoch 456
#  --------------
# Average loss of: 1.9501039538636178e-05 for train data
#
#  Epoch 457
#  --------------
# Average loss of: 1.9482413286687006e-05 for train data
#
#  Epoch 458
#  --------------
# Average loss of: 1.9463152524213e-05 for train data
#
#  Epoch 459
#  --------------
# Average loss of: 1.944463038016693e-05 for train data
#
#  Epoch 460
#  --------------
# Average loss of: 1.942517931306611e-05 for train data
#
#  Epoch 461
#  --------------
# Average loss of: 1.9406234504003804e-05 for train data
#
#  Epoch 462
#  --------------
# Average loss of: 1.938721555848133e-05 for train data
#
#  Epoch 463
#  --------------
# Average loss of: 1.936786795927219e-05 for train data
#
#  Epoch 464
#  --------------
# Average loss of: 1.9349307150605454e-05 for train data
#
#  Epoch 465
#  --------------
# Average loss of: 1.9330644084993764e-05 for train data
#
#  Epoch 466
#  --------------
# Average loss of: 1.931123093672795e-05 for train data
#
#  Epoch 467
#  --------------
# Average loss of: 1.9293038079877078e-05 for train data
#
#  Epoch 468
#  --------------
# Average loss of: 1.9274675142787602e-05 for train data
#
#  Epoch 469
#  --------------
# Average loss of: 1.925564856564961e-05 for train data
#
#  Epoch 470
#  --------------
# Average loss of: 1.9237047707338208e-05 for train data
#
#  Epoch 471
#  --------------
# Average loss of: 1.9218077351024475e-05 for train data
#
#  Epoch 472
#  --------------
# Average loss of: 1.9199915772514942e-05 for train data
#
#  Epoch 473
#  --------------
# Average loss of: 1.9181240648913443e-05 for train data
#
#  Epoch 474
#  --------------
# Average loss of: 1.9163043209846365e-05 for train data
#
#  Epoch 475
#  --------------
# Average loss of: 1.914440087589355e-05 for train data
#
#  Epoch 476
#  --------------
# Average loss of: 1.9125882597836606e-05 for train data
#
#  Epoch 477
#  --------------
# Average loss of: 1.910772265973719e-05 for train data
#
#  Epoch 478
#  --------------
# Average loss of: 1.908879722227539e-05 for train data
#
#  Epoch 479
#  --------------
# Average loss of: 1.9071148427292427e-05 for train data
#
#  Epoch 480
#  --------------
# Average loss of: 1.9052947731051972e-05 for train data
#
#  Epoch 481
#  --------------
# Average loss of: 1.903490111312749e-05 for train data
#
#  Epoch 482
#  --------------
# Average loss of: 1.9016856401049152e-05 for train data
#
#  Epoch 483
#  --------------
# Average loss of: 1.8998946679630534e-05 for train data
#
#  Epoch 484
#  --------------
# Average loss of: 1.8980657570909898e-05 for train data
#
#  Epoch 485
#  --------------
# Average loss of: 1.8963024510230754e-05 for train data
#
#  Epoch 486
#  --------------
# Average loss of: 1.894542957534213e-05 for train data
#
#  Epoch 487
#  --------------
# Average loss of: 1.89271324022684e-05 for train data
#
#  Epoch 488
#  --------------
# Average loss of: 1.8909275547775906e-05 for train data
#
#  Epoch 489
#  --------------
# Average loss of: 1.8891765408125138e-05 for train data
#
#  Epoch 490
#  --------------
# Average loss of: 1.8874525425917455e-05 for train data
#
#  Epoch 491
#  --------------
# Average loss of: 1.8856752592137126e-05 for train data
#
#  Epoch 492
#  --------------
# Average loss of: 1.883958273697317e-05 for train data
#
#  Epoch 493
#  --------------
# Average loss of: 1.8822280438325835e-05 for train data
#
#  Epoch 494
#  --------------
# Average loss of: 1.880481401249199e-05 for train data
#
#  Epoch 495
#  --------------
# Average loss of: 1.8787474440887308e-05 for train data
#
#  Epoch 496
#  --------------
# Average loss of: 1.877053421389974e-05 for train data
#
#  Epoch 497
#  --------------
# Average loss of: 1.8753105048654107e-05 for train data
#
#  Epoch 498
#  --------------
# Average loss of: 1.8736298746716786e-05 for train data
#
#  Epoch 499
#  --------------
# Average loss of: 1.8718998030271907e-05 for train data
#
#  Epoch 500
#  --------------
# Average loss of: 1.8702340095296677e-05 for train data
#
#  Epoch 501
#  --------------
# Average loss of: 1.868569274688525e-05 for train data
#
#  Epoch 502
#  --------------
# Average loss of: 1.8668727300519094e-05 for train data
#
#  Epoch 503
#  --------------
# Average loss of: 1.8652353669085643e-05 for train data
#
#  Epoch 504
#  --------------
# Average loss of: 1.8635630627568388e-05 for train data
#
#  Epoch 505
#  --------------
# Average loss of: 1.8619558537693593e-05 for train data
#
#  Epoch 506
#  --------------
# Average loss of: 1.8602659733596738e-05 for train data
#
#  Epoch 507
#  --------------
# Average loss of: 1.858628111122016e-05 for train data
#
#  Epoch 508
#  --------------
# Average loss of: 1.856983137795396e-05 for train data
#
#  Epoch 509
#  --------------
# Average loss of: 1.8553655577670726e-05 for train data
#
#  Epoch 510
#  --------------
# Average loss of: 1.8537450612302564e-05 for train data
#
#  Epoch 511
#  --------------
# Average loss of: 1.852145082757488e-05 for train data
#
#  Epoch 512
#  --------------
# Average loss of: 1.8505725811382946e-05 for train data
#
#  Epoch 513
#  --------------
# Average loss of: 1.8489574583463764e-05 for train data
#
#  Epoch 514
#  --------------
# Average loss of: 1.8473763467363823e-05 for train data
#
#  Epoch 515
#  --------------
# Average loss of: 1.8458055534483718e-05 for train data
#
#  Epoch 516
#  --------------
# Average loss of: 1.8442701259846216e-05 for train data
#
#  Epoch 517
#  --------------
# Average loss of: 1.842688868773621e-05 for train data
#
#  Epoch 518
#  --------------
# Average loss of: 1.8411542336389174e-05 for train data
#
#  Epoch 519
#  --------------
# Average loss of: 1.8395687316888143e-05 for train data
#
#  Epoch 520
#  --------------
# Average loss of: 1.8380087942750833e-05 for train data
#
#  Epoch 521
#  --------------
# Average loss of: 1.8365350174417472e-05 for train data
#
#  Epoch 522
#  --------------
# Average loss of: 1.834979910890979e-05 for train data
#
#  Epoch 523
#  --------------
# Average loss of: 1.833439014094438e-05 for train data
#
#  Epoch 524
#  --------------
# Average loss of: 1.83196533067985e-05 for train data
#
#  Epoch 525
#  --------------
# Average loss of: 1.8304204201331232e-05 for train data
#
#  Epoch 526
#  --------------
# Average loss of: 1.8288757818436352e-05 for train data
#
#  Epoch 527
#  --------------
# Average loss of: 1.8274185522659536e-05 for train data
#
#  Epoch 528
#  --------------
# Average loss of: 1.825906810995548e-05 for train data
#
#  Epoch 529
#  --------------
# Average loss of: 1.8244478387669007e-05 for train data
#
#  Epoch 530
#  --------------
# Average loss of: 1.8229671359131317e-05 for train data
#
#  Epoch 531
#  --------------
# Average loss of: 1.8215424374920985e-05 for train data
#
#  Epoch 532
#  --------------
# Average loss of: 1.820074768138511e-05 for train data
#
#  Epoch 533
#  --------------
# Average loss of: 1.818621939960394e-05 for train data
#
#  Epoch 534
#  --------------
# Average loss of: 1.81711991440352e-05 for train data
#
#  Epoch 535
#  --------------
# Average loss of: 1.81565194846371e-05 for train data
#
#  Epoch 536
#  --------------
# Average loss of: 1.814210100624223e-05 for train data
#
#  Epoch 537
#  --------------
# Average loss of: 1.812868219203665e-05 for train data
#
#  Epoch 538
#  --------------
# Average loss of: 1.811382915602735e-05 for train data
#
#  Epoch 539
#  --------------
# Average loss of: 1.8099800857226002e-05 for train data
#
#  Epoch 540
#  --------------
# Average loss of: 1.8085122560160016e-05 for train data
#
#  Epoch 541
#  --------------
# Average loss of: 1.8070952409425446e-05 for train data
#
#  Epoch 542
#  --------------
# Average loss of: 1.805701949883769e-05 for train data
#
#  Epoch 543
#  --------------
# Average loss of: 1.804324036111211e-05 for train data
#
#  Epoch 544
#  --------------
# Average loss of: 1.802994238360043e-05 for train data
#
#  Epoch 545
#  --------------
# Average loss of: 1.801551015755649e-05 for train data
#
#  Epoch 546
#  --------------
# Average loss of: 1.800097927166462e-05 for train data
#
#  Epoch 547
#  --------------
# Average loss of: 1.7987357436959428e-05 for train data
#
#  Epoch 548
#  --------------
# Average loss of: 1.7973053953028282e-05 for train data
#
#  Epoch 549
#  --------------
# Average loss of: 1.796010865950848e-05 for train data
#
#  Epoch 550
#  --------------
# Average loss of: 1.7945917770657616e-05 for train data
#
#  Epoch 551
#  --------------
# Average loss of: 1.7931985328368683e-05 for train data
#
#  Epoch 552
#  --------------
# Average loss of: 1.7918546106739088e-05 for train data
#
#  Epoch 553
#  --------------
# Average loss of: 1.7904149772630262e-05 for train data
#
#  Epoch 554
#  --------------
# Average loss of: 1.789125782984229e-05 for train data
#
#  Epoch 555
#  --------------
# Average loss of: 1.7877433945659505e-05 for train data
#
#  Epoch 556
#  --------------
# Average loss of: 1.7864501764051966e-05 for train data
#
#  Epoch 557
#  --------------
# Average loss of: 1.7850637539413582e-05 for train data
#
#  Epoch 558
#  --------------
# Average loss of: 1.7837263333603914e-05 for train data
#
#  Epoch 559
#  --------------
# Average loss of: 1.7823614990447824e-05 for train data
#
#  Epoch 560
#  --------------
# Average loss of: 1.780960907003646e-05 for train data
#
#  Epoch 561
#  --------------
# Average loss of: 1.7796550252660382e-05 for train data
#
#  Epoch 562
#  --------------
# Average loss of: 1.7782769037921754e-05 for train data
#
#  Epoch 563
#  --------------
# Average loss of: 1.7769670661255076e-05 for train data
#
#  Epoch 564
#  --------------
# Average loss of: 1.7755741015571402e-05 for train data
#
#  Epoch 565
#  --------------
# Average loss of: 1.774322443161509e-05 for train data
#
#  Epoch 566
#  --------------
# Average loss of: 1.7729238562560568e-05 for train data
#
#  Epoch 567
#  --------------
# Average loss of: 1.771638581244588e-05 for train data
#
#  Epoch 568
#  --------------
# Average loss of: 1.7702974225039726e-05 for train data
#
#  Epoch 569
#  --------------
# Average loss of: 1.7689395109619e-05 for train data
#
#  Epoch 570
#  --------------
# Average loss of: 1.7676558689436207e-05 for train data
#
#  Epoch 571
#  --------------
# Average loss of: 1.766278928794236e-05 for train data
#
#  Epoch 572
#  --------------
# Average loss of: 1.764952974258449e-05 for train data
#
#  Epoch 573
#  --------------
# Average loss of: 1.763677515782547e-05 for train data
#
#  Epoch 574
#  --------------
# Average loss of: 1.7623464025518843e-05 for train data
#
#  Epoch 575
#  --------------
# Average loss of: 1.7610370231250272e-05 for train data
#
#  Epoch 576
#  --------------
# Average loss of: 1.7597243795125907e-05 for train data
#
#  Epoch 577
#  --------------
# Average loss of: 1.7583947153889313e-05 for train data
#
#  Epoch 578
#  --------------
# Average loss of: 1.757099399046638e-05 for train data
#
#  Epoch 579
#  --------------
# Average loss of: 1.755788200734969e-05 for train data
#
#  Epoch 580
#  --------------
# Average loss of: 1.7545008789238636e-05 for train data
#
#  Epoch 581
#  --------------
# Average loss of: 1.7531911811101963e-05 for train data
#
#  Epoch 582
#  --------------
# Average loss of: 1.751863800918727e-05 for train data
#
#  Epoch 583
#  --------------
# Average loss of: 1.750606647328823e-05 for train data
#
#  Epoch 584
#  --------------
# Average loss of: 1.749313228956453e-05 for train data
#
#  Epoch 585
#  --------------
# Average loss of: 1.7479991374057136e-05 for train data
#
#  Epoch 586
#  --------------
# Average loss of: 1.746763394876325e-05 for train data
#
#  Epoch 587
#  --------------
# Average loss of: 1.7454824841161098e-05 for train data
#
#  Epoch 588
#  --------------
# Average loss of: 1.7442085069797032e-05 for train data
#
#  Epoch 589
#  --------------
# Average loss of: 1.742969378028647e-05 for train data
#
#  Epoch 590
#  --------------
# Average loss of: 1.7417177801507932e-05 for train data
#
#  Epoch 591
#  --------------
# Average loss of: 1.7404935236299935e-05 for train data
#
#  Epoch 592
#  --------------
# Average loss of: 1.7392070729601984e-05 for train data
#
#  Epoch 593
#  --------------
# Average loss of: 1.7380145124479897e-05 for train data
#
#  Epoch 594
#  --------------
# Average loss of: 1.736791373896267e-05 for train data
#
#  Epoch 595
#  --------------
# Average loss of: 1.735608732797118e-05 for train data
#
#  Epoch 596
#  --------------
# Average loss of: 1.734394449231331e-05 for train data
#
#  Epoch 597
#  --------------
# Average loss of: 1.733173592770072e-05 for train data
#
#  Epoch 598
#  --------------
# Average loss of: 1.7320078268176076e-05 for train data
#
#  Epoch 599
#  --------------
# Average loss of: 1.7307650479415315e-05 for train data
#
#  Epoch 600
#  --------------
# Average loss of: 1.7296503500438122e-05 for train data
#
#  Epoch 601
#  --------------
# Average loss of: 1.728539226196517e-05 for train data
#
#  Epoch 602
#  --------------
# Average loss of: 1.7273313802161284e-05 for train data
#
#  Epoch 603
#  --------------
# Average loss of: 1.7261979205386524e-05 for train data
#
#  Epoch 604
#  --------------
# Average loss of: 1.7250775353750214e-05 for train data
#
#  Epoch 605
#  --------------
# Average loss of: 1.7239203789722523e-05 for train data
#
#  Epoch 606
#  --------------
# Average loss of: 1.722874802962906e-05 for train data
#
#  Epoch 607
#  --------------
# Average loss of: 1.721682933507509e-05 for train data
#
#  Epoch 608
#  --------------
# Average loss of: 1.7205916844523017e-05 for train data
#
#  Epoch 609
#  --------------
# Average loss of: 1.7195033929647253e-05 for train data
#
#  Epoch 610
#  --------------
# Average loss of: 1.7183876703802526e-05 for train data
#
#  Epoch 611
#  --------------
# Average loss of: 1.7172965319650757e-05 for train data
#
#  Epoch 612
#  --------------
# Average loss of: 1.7161438273706153e-05 for train data
#
#  Epoch 613
#  --------------
# Average loss of: 1.715106014844423e-05 for train data
#
#  Epoch 614
#  --------------
# Average loss of: 1.714029845852565e-05 for train data
#
#  Epoch 615
#  --------------
# Average loss of: 1.7129446164835825e-05 for train data
#
#  Epoch 616
#  --------------
# Average loss of: 1.7118728272134833e-05 for train data
#
#  Epoch 617
#  --------------
# Average loss of: 1.710806967894314e-05 for train data
#
#  Epoch 618
#  --------------
# Average loss of: 1.70976021167462e-05 for train data
#
#  Epoch 619
#  --------------
# Average loss of: 1.708699869841439e-05 for train data
#
#  Epoch 620
#  --------------
# Average loss of: 1.707610045114052e-05 for train data
#
#  Epoch 621
#  --------------
# Average loss of: 1.706581207540694e-05 for train data
#
#  Epoch 622
#  --------------
# Average loss of: 1.7054871769823877e-05 for train data
#
#  Epoch 623
#  --------------
# Average loss of: 1.7044443732038416e-05 for train data
#
#  Epoch 624
#  --------------
# Average loss of: 1.7034018485310298e-05 for train data
#
#  Epoch 625
#  --------------
# Average loss of: 1.7023114699350118e-05 for train data
#
#  Epoch 626
#  --------------
# Average loss of: 1.7012782066240106e-05 for train data
#
#  Epoch 627
#  --------------
# Average loss of: 1.7002731848469922e-05 for train data
#
#  Epoch 628
#  --------------
# Average loss of: 1.6991613298750964e-05 for train data
#
#  Epoch 629
#  --------------
# Average loss of: 1.698158653662176e-05 for train data
#
#  Epoch 630
#  --------------
# Average loss of: 1.69709407738992e-05 for train data
#
#  Epoch 631
#  --------------
# Average loss of: 1.6960448748068304e-05 for train data
#
#  Epoch 632
#  --------------
# Average loss of: 1.69505360506264e-05 for train data
#
#  Epoch 633
#  --------------
# Average loss of: 1.6940310263726132e-05 for train data
#
#  Epoch 634
#  --------------
# Average loss of: 1.69300508989636e-05 for train data
#
#  Epoch 635
#  --------------
# Average loss of: 1.6918989370651614e-05 for train data
#
#  Epoch 636
#  --------------
# Average loss of: 1.6908498953353045e-05 for train data
#
#  Epoch 637
#  --------------
# Average loss of: 1.6898861942718212e-05 for train data
#
#  Epoch 638
#  --------------
# Average loss of: 1.6888478237979144e-05 for train data
#
#  Epoch 639
#  --------------
# Average loss of: 1.6878142584891976e-05 for train data
#
#  Epoch 640
#  --------------
# Average loss of: 1.6867450694871878e-05 for train data
#
#  Epoch 641
#  --------------
# Average loss of: 1.685778348596614e-05 for train data
#
#  Epoch 642
#  --------------
# Average loss of: 1.684683464986847e-05 for train data
#
#  Epoch 643
#  --------------
# Average loss of: 1.6837610897482592e-05 for train data
#
#  Epoch 644
#  --------------
# Average loss of: 1.6827156619410742e-05 for train data
#
#  Epoch 645
#  --------------
# Average loss of: 1.6816920740620845e-05 for train data
#
#  Epoch 646
#  --------------
# Average loss of: 1.680669878437584e-05 for train data
#
#  Epoch 647
#  --------------
# Average loss of: 1.6796477309253533e-05 for train data
#
#  Epoch 648
#  --------------
# Average loss of: 1.678637615559637e-05 for train data
#
#  Epoch 649
#  --------------
# Average loss of: 1.6776483441799427e-05 for train data
#
#  Epoch 650
#  --------------
# Average loss of: 1.6765786673704497e-05 for train data
#
#  Epoch 651
#  --------------
# Average loss of: 1.6755987727810862e-05 for train data
#
#  Epoch 652
#  --------------
# Average loss of: 1.6745708793905577e-05 for train data
#
#  Epoch 653
#  --------------
# Average loss of: 1.673648919008883e-05 for train data
#
#  Epoch 654
#  --------------
# Average loss of: 1.6725954200046546e-05 for train data
#
#  Epoch 655
#  --------------
# Average loss of: 1.6716014452549645e-05 for train data
#
#  Epoch 656
#  --------------
# Average loss of: 1.6706248699620118e-05 for train data
#
#  Epoch 657
#  --------------
# Average loss of: 1.6695562889981376e-05 for train data
#
#  Epoch 658
#  --------------
# Average loss of: 1.6686110398086383e-05 for train data
#
#  Epoch 659
#  --------------
# Average loss of: 1.6676139925357346e-05 for train data
#
#  Epoch 660
#  --------------
# Average loss of: 1.6666156986821078e-05 for train data
#
#  Epoch 661
#  --------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [47], in <cell line: 21>()
#      30 print(f"\n Epoch {epoch_counter} \n --------------")
#      31 # Train
# ---> 32 train_loop(train_dataloader, model, loss_fn, optimizer)
#      33 # Test on the training data
#      34 average_train_loss = test_loop(train_dataloader, model, loss_fn)
#
# Input In [45], in train_loop(dataloader, model, loss_fn, optimizer, report_progress, regularization)
#       9 # Backpropagation
#      10 optimizer.zero_grad()
# ---> 11 loss.backward()
#      12 optimizer.step()
#      14 # If we want to report progress during training (not recommended - obstructs view)
#
# File D:\Anaconda3\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File D:\Anaconda3\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Results of training

# %%
# Plot it
plt.figure()
lw = 1
ms = 2
plt.plot(train_losses, 'o--', color = 'red', label = 'Train set', lw = lw, ms = ms)
plt.plot(test_losses, 'o--', color = 'blue', label = "Test set", lw = lw, ms = ms)
plt.legend()
plt.grid()
plt.xlabel("Epoch")
xt_step = 50
xt = [i*xt_step for i in range(len(train_losses)//xt_step+2)]
plt.xticks(xt)
plt.ylabel(r'$L$')
plt.axhline(0, color = 'black', alpha = 0.7)
plt.title("Loss")
# Plot when we adapted learning rate
for t in adaptation_indices:
    plt.axvline(t+200, linestyle = "--", color = 'black', alpha = 0.5, lw = 1)
plt.yscale('log')
# plt.ylim(10**(-9))
# plt.savefig("Plots/NNC2Pv1.pdf", bbox_inches = 'tight')
plt.show()

# %%
# torch.save(model, 'Models/NNC2Pv1.pth')

# %% [markdown]
# # Analyzing neural networks

# %% [markdown]
# We import NNC2Pv0, which beats the performance of the models in the paper.

# %%
NNC2P = torch.load('Models/NNC2Pv0t2.pth')

# %% [markdown]
# ## Estimate the performance of the network

# %%
def L1_norm(predictions, y):
    """Here, predictions and y are arrays for one specific quantity, eg pressure. See table 1"""
    return np.sum(abs(predictions - y))/len(predictions)

# %%
def Linfty_norm(predictions, y):
    """Here, predictions and y are arrays for one specific quantity, eg pressure. See table 1"""
    return max(abs(predictions - y))

# %%
# Get features and labels
test_features = test_data.features
test_labels = test_data.labels
test_features[:4]
# Out:
# [tensor([10.2041, 12.0266, 22.1313]),
#  tensor([ 7.0046, 22.3374, 21.0772]),
#  tensor([ 9.5747, 10.5188, 10.0152]),
#  tensor([0.7725, 1.8519, 1.8100])]

# %%
test_features[0]
# Out:
# tensor([10.2041, 12.0266, 22.1313])

# %% [markdown]
# ##### What is the performance of a randomly pruned NN?

# %%
number = 20
new_model = prune_nn(NNC2P, number=number)
model = new_model
models = [NNC2P, new_model]
names = ["NNC2P", "pruned"]

for i in range(len(models)):
    # Get model and name
    model = models[i]
    name = names[i]

    # Get predictions
    with torch.no_grad():
        p_hat= np.array([])
        for input_values in test_features:
            prediction = model(input_values)
            p_hat = np.append(p_hat, prediction[0].item())

    # Get labels as np arrays
    p = np.array([])
    for value in test_labels:
        p = np.append(p, value.item())

    # Get the errors:
    delta_p_L1       = L1_norm(p_hat, p)
    delta_p_Linfty = Linfty_norm(p_hat, p)

    print("Errors for p: %e  with L1 and %e with Linfty for %s with %d neurons pruned" % (delta_p_L1, delta_p_Linfty, name, number) )
# Out:
# Errors for p: 2.623259e-04  with L1 and 8.344986e-03 with Linfty for NNC2P with 20 neurons pruned
# Errors for p: 2.649312e-01  with L1 and 1.045513e+00 with Linfty for pruned with 20 neurons pruned
